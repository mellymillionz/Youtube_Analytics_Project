# %%
import requests
from bs4 import BeautifulSoup as BS
import requests
import json
import mysql.connector
import pandas as pd
import config
import seaborn as sns

db = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = "youtube")

cursor = db.cursor()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-ebcda6ebc7bc> in <module>
#       5 import mysql.connector
#       6 import pandas as pd
# ----> 7 import config
#       8 import seaborn as sns
#       9
#
# ModuleNotFoundError: No module named 'config'

# %% [markdown]
# # Database and Table Creation

# %%
#create database
from mysql.connector import errorcode
db_name = 'youtube'

def create_database(cursor, database):
    try:
        cursor.execute(
            "CREATE DATABASE {} DEFAULT CHARACTER SET 'utf8'".format(database))
    except mysql.connector.Error as err:
        print("Failed creating database: {}".format(err))
        exit(1)

try:
    cursor.execute("USE {}".format(db_name))
except mysql.connector.Error as err:
    print("Database {} does not exists.".format(db_name))
    if err.errno == errorcode.ER_BAD_DB_ERROR:
        create_database(cursor, db_name)
        print("Database {} created successfully.".format(db_name))
        cnx.database = db_name
    else:
        print(err)
        exit(1)
        
# create_database(cursor, db_name)
# Out:
# Failed creating database: 1007 (HY000): Can't create database 'youtube'; database exists

# %%
#Create table for channel data only

db_name = 'youtube'

create_query = """
CREATE TABLE channels (
    channel_id varchar(40) NOT NULL, 
    channel_title varchar(60) NOT NULL UNIQUE, 
    creation_date datetime, 
    country varchar(20), 
    view_count bigint NOT NULL,
    comment_count int,
    subscriber_count int NOT NULL,
    video_count int NOT NULL,
    CONSTRAINT primary_key PRIMARY KEY(channel_id)
    );

"""
cursor.execute(create_query)

# %%
#create table for the genre and channel ids
create_query = """
      CREATE TABLE genres
    (
      genre_name varchar(50),
      channel_id varchar(40) NOT NULL, 
      FOREIGN KEY (channel_id) REFERENCES channels(channel_id)  
      )
    """
cursor.execute(create_query)

# %% [markdown]
# # Webscraping for Top Channel Names

# %%
youtube = requests.get('https://www.tubefilter.com/2019/06/11/top-50-most-viewed-youtube-channels-worldwide-2019-06-09/')
soup1 = BS(youtube.content, 'html.parser')
soup1.prettify()
info1 = soup1.find_all(id = 'ytChart')
channels = info1[0].find_all(class_='channelName')
channels2 = channels[0].find_all('href')

# %% [markdown]
# First attempt at scraping from tubefilter.come

# %%
def get_name(channels):
        names = []
        for name in channels:
            name1 = name.find('a').text
            names.append(name1)           
        return names

channel_names = get_name(channels)
channel_names[:5]
# Out:
# []

# %% [markdown]
# # Import CSV of Youtube Channel Names

# %% [markdown]
# #Clean and Import Top Channel Names:

# %%
all_titles = pd.read_csv('Workbook1.csv', encoding = "ISO-8859-1")

column_names = ['channel']
all_titles.columns = [x for x in column_names]
all_titles['channel'] = all_titles['channel'].str.rstrip('æ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b8c0a1072b8e> in <module>
# ----> 1 all_titles = pd.read_csv('Workbook1.csv', encoding = "ISO-8859-1")
#       2
#       3 column_names = ['channel']
#       4 all_titles.columns = [x for x in column_names]
#       5 all_titles['channel'] = all_titles['channel'].str.rstrip('æ')
#
# NameError: name 'pd' is not defined

# %%
#Clean channel name Dataframe 
first_channels = pd.read_csv("channel_set_final.csv")
channels_df = first_channels.drop(columns = 'genres')
channels_df2 = channels_df.fillna(value='Null')

# %%
#Convert to dictionary
first_channels_dict = channels_df2.to_dict(orient='records')
first_channels_dict
# Out:
# [{'Unnamed: 0': 0,
#   'channel_id': 'UCa10nxShhzNrCE1o2ZOPztg',
#   'channel_title': 'Trap Nation',
#   'creation_date': '2012-09-23T03:23:23.000Z',
#   'country': 'US',
#   'view_count': 10040910795,
#   'comment_count': 0,
#   'subscriber_count': 27600000,
#   'video_count': 1814},
#  {'Unnamed: 0': 1,
#   'channel_id': 'UClZkHt2kNIgyrTTPnSQV3SA',
#   'channel_title': 'Get Movies',
#   'creation_date': '2006-12-16T19:24:29.000Z',
#   'country': 'RU',
#   'view_count': 21779486367,
#   'comment_count': 0,
#   'subscriber_count': 29100000,
#   'video_count': 2986},
#  {'Unnamed: 0': 2,
#   'channel_id': 'UCYWOjHweP2V-8kGKmmAmQJQ',
#   'channel_title': 'Badabun',
#   'creation_date': '2014-10-14T00:15:54.000Z',
#   'country': 'MX',
#   'view_count': 14839639855,
#   'comment_count': 0,
#   'subscriber_count': 43100000,
#   'video_count': 4880},
#  {'Unnamed: 0': 3,
#   'channel_id': 'UCJplp5SjeGSdVdwsfb9Q7lQ',
#   'channel_title': 'Like Nastya Vlog',
#   'creation_date': '2016-12-06T12:15:52.000Z',
#   'country': 'RU',
#   'view_count': 19158328941,
#   'comment_count': 0,
#   'subscriber_count': 39100000,
#   'video_count': 327},
#  {'Unnamed: 0': 4,
#   'channel_id': 'UCP6uH_XlsxrXwZQ4DlqbqPg',
#   'channel_title': 'Shemaroo Filmi Gaane',
#   'creation_date': '2010-06-11T05:33:27.000Z',
#   'country': 'IN',
#   'view_count': 13883702142,
#   'comment_count': 0,
#   'subscriber_count': 29500000,
#   'video_count': 6348},
#  {'Unnamed: 0': 5,
#   'channel_id': 'UCJ5v_MCY6GNUBTO8-D3XoAg',
#   'channel_title': 'WWE',
#   'creation_date': '2007-05-11T01:20:02.000Z',
#   'country': 'Null',
#   'view_count': 37182753702,
#   'comment_count': 0,
#   'subscriber_count': 50800000,
#   'video_count': 44501},
#  {'Unnamed: 0': 6,
#   'channel_id': 'UCBVjMGOIkavEAhyqpxJ73Dw',
#   'channel_title': 'Maroon 5',
#   'creation_date': '2006-03-09T03:19:51.000Z',
#   'country': 'Null',
#   'view_count': 274747243,
#   'comment_count': 0,
#   'subscriber_count': 28100000,
#   'video_count': 154},
#  {'Unnamed: 0': 7,
#   'channel_id': 'UCOmHUn--16B90oW2L6FRR3A',
#   'channel_title': 'BLACKPINK',
#   'creation_date': '2016-06-29T03:15:23.000Z',
#   'country': 'KR',
#   'view_count': 7780183503,
#   'comment_count': 0,
#   'subscriber_count': 31300000,
#   'video_count': 253},
#  {'Unnamed: 0': 8,
#   'channel_id': 'UCpEhnqL0y41EpW2TvWAHD7Q',
#   'channel_title': 'SET India',
#   'creation_date': '2006-09-20T22:24:59.000Z',
#   'country': 'IN',
#   'view_count': 43125038812,
#   'comment_count': 0,
#   'subscriber_count': 59300000,
#   'video_count': 33607},
#  {'Unnamed: 0': 9,
#   'channel_id': 'UCyoXW-Dse7fURq30EWl_CUA',
#   'channel_title': 'Goldmines Telefilms',
#   'creation_date': '2012-01-21T08:42:21.000Z',
#   'country': 'IN',
#   'view_count': 5237261807,
#   'comment_count': 0,
#   'subscriber_count': 29300000,
#   'video_count': 512},
#  {'Unnamed: 0': 10,
#   'channel_id': 'UCRijo3ddMTht_IHyNSNXpNQ',
#   'channel_title': 'Dude Perfect',
#   'creation_date': '2009-03-17T05:44:36.000Z',
#   'country': 'US',
#   'view_count': 9306672097,
#   'comment_count': 0,
#   'subscriber_count': 47200000,
#   'video_count': 218},
#  {'Unnamed: 0': 11,
#   'channel_id': 'UCECJDeK0MNapZbpaOzxrUPA',
#   'channel_title': 'Luisito Comunica',
#   'creation_date': '2012-04-15T04:13:36.000Z',
#   'country': 'MX',
#   'view_count': 3639444196,
#   'comment_count': 0,
#   'subscriber_count': 27600000,
#   'video_count': 714},
#  {'Unnamed: 0': 13,
#   'channel_id': 'UC9CoOnJkIBMdeijd9qYoT_g',
#   'channel_title': 'Ariana Grande',
#   'creation_date': '2007-01-22T01:53:12.000Z',
#   'country': 'Null',
#   'view_count': 925980874,
#   'comment_count': 0,
#   'subscriber_count': 38800000,
#   'video_count': 139},
#  {'Unnamed: 0': 14,
#   'channel_id': 'UCbCmjCuTUZos6Inko4u57UQ',
#   'channel_title': 'Cocomelon - Nursery Rhymes',
#   'creation_date': '2006-09-01T22:18:49.000Z',
#   'country': 'US',
#   'view_count': 43335002834,
#   'comment_count': 0,
#   'subscriber_count': 65100000,
#   'video_count': 474},
#  {'Unnamed: 0': 15,
#   'channel_id': 'UCb2HGwORFBo94DmRx4oLzow',
#   'channel_title': 'One Direction',
#   'creation_date': '2010-12-03T11:45:50.000Z',
#   'country': 'Null',
#   'view_count': 352206340,
#   'comment_count': 0,
#   'subscriber_count': 30200000,
#   'video_count': 157},
#  {'Unnamed: 0': 16,
#   'channel_id': 'UC3KQ5GWANYF8lChqjZpXsQw',
#   'channel_title': 'whinderssonnunes',
#   'creation_date': '2013-01-21T13:06:10.000Z',
#   'country': 'Null',
#   'view_count': 3142901781,
#   'comment_count': 0,
#   'subscriber_count': 37500000,
#   'video_count': 373},
#  {'Unnamed: 0': 17,
#   'channel_id': 'UC56gTxNs4f9xZ7Pa2i5xNzg',
#   'channel_title': 'Sony Music India',
#   'creation_date': '2009-09-02T23:16:22.000Z',
#   'country': 'IN',
#   'view_count': 11463666094,
#   'comment_count': 0,
#   'subscriber_count': 28800000,
#   'video_count': 2498},
#  {'Unnamed: 0': 18,
#   'channel_id': 'UC4rlAVgAK0SGk-yTfe48Qpw',
#   'channel_title': 'BRIGHT SIDE',
#   'creation_date': '2017-03-15T11:17:50.000Z',
#   'country': 'Null',
#   'view_count': 6075130166,
#   'comment_count': 0,
#   'subscriber_count': 31600000,
#   'video_count': 3034},
#  {'Unnamed: 0': 19,
#   'channel_id': 'UCam8T03EOFBsNdR0thrFHdQ',
#   'channel_title': 'VEGETTA777',
#   'creation_date': '2008-03-02T19:25:21.000Z',
#   'country': 'Null',
#   'view_count': 11275900934,
#   'comment_count': 0,
#   'subscriber_count': 27900000,
#   'video_count': 5571},
#  {'Unnamed: 0': 20,
#   'channel_id': 'UC295-Dw_tDNtZXFeAPAW6Aw',
#   'channel_title': '5-Minute Crafts',
#   'creation_date': '2016-11-15T09:25:37.000Z',
#   'country': 'US',
#   'view_count': 16284872101,
#   'comment_count': 0,
#   'subscriber_count': 62000000,
#   'video_count': 3819},
#  {'Unnamed: 0': 21,
#   'channel_id': 'UCXazgXDIYyWH-yXLAkcrFxw',
#   'channel_title': 'elrubiusOMG',
#   'creation_date': '2011-12-20T00:48:42.000Z',
#   'country': 'Null',
#   'view_count': 8095913699,
#   'comment_count': 0,
#   'subscriber_count': 36100000,
#   'video_count': 816},
#  {'Unnamed: 0': 22,
#   'channel_id': 'UC3IZKseVpdzPSBaWxBxundA',
#   'channel_title': 'ibighit',
#   'creation_date': '2008-06-04T08:23:22.000Z',
#   'country': 'Null',
#   'view_count': 7314456972,
#   'comment_count': 0,
#   'subscriber_count': 30100000,
#   'video_count': 336},
#  {'Unnamed: 0': 23,
#   'channel_id': 'UCIwFjwMjI0y7PDBVEO9-bkQ',
#   'channel_title': 'Justin Bieber',
#   'creation_date': '2007-01-15T21:17:27.000Z',
#   'country': 'Null',
#   'view_count': 636976987,
#   'comment_count': 0,
#   'subscriber_count': 47200000,
#   'video_count': 135},
#  {'Unnamed: 0': 24,
#   'channel_id': 'UCEdvpU2pFRCVqU6yIPyTpMQ',
#   'channel_title': 'Marshmello',
#   'creation_date': '2015-04-06T21:21:50.000Z',
#   'country': 'US',
#   'view_count': 7568272336,
#   'comment_count': 0,
#   'subscriber_count': 40800000,
#   'video_count': 383},
#  {'Unnamed: 0': 25,
#   'channel_id': 'UCV4xOVpbcV8SdueDCOxLXtQ',
#   'channel_title': 'Fernanfloo',
#   'creation_date': '2011-05-02T05:32:42.000Z',
#   'country': 'SV',
#   'view_count': 7519676900,
#   'comment_count': 0,
#   'subscriber_count': 34100000,
#   'video_count': 534},
#  {'Unnamed: 0': 26,
#   'channel_id': 'UC3gNmTGu-TTbFPpfSs5kNkg',
#   'channel_title': 'Movieclips',
#   'creation_date': '2006-04-28T00:02:37.000Z',
#   'country': 'US',
#   'view_count': 28869831031,
#   'comment_count': 0,
#   'subscriber_count': 30900000,
#   'video_count': 34528},
#  {'Unnamed: 0': 27,
#   'channel_id': 'UCK1i2UviaXLUNrZlAFpw_jA',
#   'channel_title': 'El Reino Infantil',
#   'creation_date': '2011-06-02T16:20:07.000Z',
#   'country': 'Null',
#   'view_count': 24788523758,
#   'comment_count': 0,
#   'subscriber_count': 27800000,
#   'video_count': 751},
#  {'Unnamed: 0': 28,
#   'channel_id': 'UCHkj014U2CQ2Nv0UZeYpE_A',
#   'channel_title': 'JustinBieberVEVO',
#   'creation_date': '2009-09-26T03:46:15.000Z',
#   'country': 'US',
#   'view_count': 19168870236,
#   'comment_count': 0,
#   'subscriber_count': 33200000,
#   'video_count': 122},
#  {'Unnamed: 0': 29,
#   'channel_id': 'UCFFbwnve3yF62-tVXkTyHqg',
#   'channel_title': 'Zee Music Company',
#   'creation_date': '2014-03-12T11:59:25.000Z',
#   'country': 'IN',
#   'view_count': 21403917219,
#   'comment_count': 0,
#   'subscriber_count': 46100000,
#   'video_count': 4386},
#  {'Unnamed: 0': 30,
#   'channel_id': 'UCcgqSM4YEo5vVQpqwN-MaNw',
#   'channel_title': 'Rihanna',
#   'creation_date': '2005-11-06T16:14:28.000Z',
#   'country': 'Null',
#   'view_count': 62978109,
#   'comment_count': 0,
#   'subscriber_count': 33200000,
#   'video_count': 78},
#  {'Unnamed: 0': 31,
#   'channel_id': 'UCZJ7m7EnCNodqnu5SAtg8eQ',
#   'channel_title': 'HolaSoyGerman.',
#   'creation_date': '2011-09-08T20:25:54.000Z',
#   'country': 'CL',
#   'view_count': 4078891171,
#   'comment_count': 0,
#   'subscriber_count': 40000000,
#   'video_count': 137},
#  {'Unnamed: 0': 32,
#   'channel_id': 'UCffDXn7ycAzwL2LDlbyWOTw',
#   'channel_title': 'Canal KondZilla',
#   'creation_date': '2012-03-21T23:40:47.000Z',
#   'country': 'BR',
#   'view_count': 27167895228,
#   'comment_count': 0,
#   'subscriber_count': 53200000,
#   'video_count': 1232},
#  {'Unnamed: 0': 34,
#   'channel_id': 'UCq-Fj5jknLsUf-MWSy4_brA',
#   'channel_title': 'T-Series',
#   'creation_date': '2006-03-13T14:27:05.000Z',
#   'country': 'IN',
#   'view_count': 88630702566,
#   'comment_count': 0,
#   'subscriber_count': 118000000,
#   'video_count': 14009},
#  {'Unnamed: 0': 35,
#   'channel_id': 'UCvlE5gTbOvjiolFlEm-c_Ow',
#   'channel_title': 'Vlad and Nikita',
#   'creation_date': '2018-04-23T13:58:18.000Z',
#   'country': 'US',
#   'view_count': 12558898052,
#   'comment_count': 0,
#   'subscriber_count': 29300000,
#   'video_count': 174},
#  {'Unnamed: 0': 36,
#   'channel_id': 'UCYiGq8XF7YQD00x7wAd62Zg',
#   'channel_title': 'JuegaGerman',
#   'creation_date': '2013-05-19T00:09:13.000Z',
#   'country': 'CL',
#   'view_count': 10111923159,
#   'comment_count': 0,
#   'subscriber_count': 37100000,
#   'video_count': 1665},
#  {'Unnamed: 0': 37,
#   'channel_id': 'UCJrOtniJ0-NWz37R30urifQ',
#   'channel_title': 'Alan Walker',
#   'creation_date': '2012-08-25T20:55:38.000Z',
#   'country': 'NO',
#   'view_count': 7266590697,
#   'comment_count': 0,
#   'subscriber_count': 30600000,
#   'video_count': 207},
#  {'Unnamed: 0': 38,
#   'channel_id': 'UC-lHJZR3Gqxm24_Vd_AJ5Yw',
#   'channel_title': 'PewDiePie',
#   'creation_date': '2010-04-29T10:54:00.000Z',
#   'country': 'US',
#   'view_count': 23936169110,
#   'comment_count': 0,
#   'subscriber_count': 102000000,
#   'video_count': 4010},
#  {'Unnamed: 0': 39,
#   'channel_id': 'UCV306eHqgo0LvBf3Mh36AHg',
#   'channel_title': 'Felipe Neto',
#   'creation_date': '2006-05-16T06:56:06.000Z',
#   'country': 'BR',
#   'view_count': 8184018380,
#   'comment_count': 0,
#   'subscriber_count': 34900000,
#   'video_count': 2047},
#  {'Unnamed: 0': 40,
#   'channel_id': 'UCqECaJ8Gagnn7YCbPEzWH6g',
#   'channel_title': 'Taylor Swift',
#   'creation_date': '2006-09-20T21:05:35.000Z',
#   'country': 'Null',
#   'view_count': 293588438,
#   'comment_count': 0,
#   'subscriber_count': 36300000,
#   'video_count': 174},
#  {'Unnamed: 0': 42,
#   'channel_id': 'UCfM3zsQsOnfWNUppiycmBuw',
#   'channel_title': 'EminemMusic',
#   'creation_date': '2007-02-09T00:01:36.000Z',
#   'country': 'Null',
#   'view_count': 759284667,
#   'comment_count': 0,
#   'subscriber_count': 39600000,
#   'video_count': 117},
#  {'Unnamed: 0': 43,
#   'channel_id': 'UCp0hYYBW6IMayGgR-WeoCvQ',
#   'channel_title': 'TheEllenShow',
#   'creation_date': '2006-11-21T04:53:43.000Z',
#   'country': 'US',
#   'view_count': 17945264458,
#   'comment_count': 0,
#   'subscriber_count': 35200000,
#   'video_count': 10998},
#  {'Unnamed: 0': 44,
#   'channel_id': 'UCYvmuw-JtVrTZQ-7Y4kd63Q',
#   'channel_title': 'Katy Perry',
#   'creation_date': '2008-06-01T19:58:36.000Z',
#   'country': 'Null',
#   'view_count': 364182786,
#   'comment_count': 0,
#   'subscriber_count': 35500000,
#   'video_count': 103},
#  {'Unnamed: 0': 45,
#   'channel_id': 'UC0C-w0YjGpqDXGB8IHb662A',
#   'channel_title': 'Ed Sheeran',
#   'creation_date': '2006-08-08T13:59:50.000Z',
#   'country': 'Null',
#   'view_count': 18525689218,
#   'comment_count': 0,
#   'subscriber_count': 42700000,
#   'video_count': 158},
#  {'Unnamed: 0': 46,
#   'channel_id': 'UCAvCL8hyXjSUHKEGuUPr1BA',
#   'channel_title': 'Shawn Mendes',
#   'creation_date': '2011-01-19T00:16:50.000Z',
#   'country': 'Null',
#   'view_count': 291495285,
#   'comment_count': 0,
#   'subscriber_count': 24200000,
#   'video_count': 88},
#  {'Unnamed: 0': 47,
#   'channel_id': 'UC9TO_oo4c_LrOiKNaY6aysA',
#   'channel_title': 'Daddy Yankee',
#   'creation_date': '2011-05-16T22:30:49.000Z',
#   'country': 'PR',
#   'view_count': 9378561820,
#   'comment_count': 0,
#   'subscriber_count': 25800000,
#   'video_count': 349},
#  {'Unnamed: 0': 48,
#   'channel_id': 'UCbW18JZRgko_mOGm5er8Yzg',
#   'channel_title': 'OneDirectionVEVO',
#   'creation_date': '2010-12-04T21:25:34.000Z',
#   'country': 'Null',
#   'view_count': 9033082007,
#   'comment_count': 0,
#   'subscriber_count': 22900000,
#   'video_count': 171},
#  {'Unnamed: 0': 49,
#   'channel_id': 'UCstEtN0pgOmCf02EdXsGChw',
#   'channel_title': 'ABS-CBN Entertainment',
#   'creation_date': '2008-07-16T02:11:59.000Z',
#   'country': 'PH',
#   'view_count': 30858673786,
#   'comment_count': 0,
#   'subscriber_count': 22900000,
#   'video_count': 132111},
#  {'Unnamed: 0': 50,
#   'channel_id': 'UCBNs31xysxpAGMheg8OrngA',
#   'channel_title': 'Yuya',
#   'creation_date': '2009-09-20T22:17:26.000Z',
#   'country': 'Null',
#   'view_count': 2449082537,
#   'comment_count': 0,
#   'subscriber_count': 24100000,
#   'video_count': 618},
#  {'Unnamed: 0': 51,
#   'channel_id': 'UC3MLnJtqc_phABBriLRhtgQ',
#   'channel_title': 'SonyMusicIndiaVEVO',
#   'creation_date': '2009-09-02T23:38:43.000Z',
#   'country': 'Null',
#   'view_count': 11922394140,
#   'comment_count': 0,
#   'subscriber_count': 25900000,
#   'video_count': 3025},
#  {'Unnamed: 0': 52,
#   'channel_id': 'UCaWd5_7JhbQBe4dknZhsHJg',
#   'channel_title': 'WatchMojo.com',
#   'creation_date': '2007-01-25T16:19:35.000Z',
#   'country': 'CA',
#   'view_count': 12766228835,
#   'comment_count': 0,
#   'subscriber_count': 21500000,
#   'video_count': 17369},
#  {'Unnamed: 0': 53,
#   'channel_id': 'UCOsyDsO5tIt-VZ1iwjdQmew',
#   'channel_title': 'Speed Records',
#   'creation_date': '2012-11-22T10:36:15.000Z',
#   'country': 'IN',
#   'view_count': 13291361579,
#   'comment_count': 0,
#   'subscriber_count': 26500000,
#   'video_count': 7483},
#  {'Unnamed: 0': 54,
#   'channel_id': 'UCaayLD9i5x4MmIoVZxXSv_g',
#   'channel_title': 'T-Series Bhakti Sagar',
#   'creation_date': '2011-02-13T18:21:00.000Z',
#   'country': 'IN',
#   'view_count': 9862040722,
#   'comment_count': 0,
#   'subscriber_count': 24500000,
#   'video_count': 20345},
#  {'Unnamed: 0': 55,
#   'channel_id': 'UCSAUGyc_xA8uYzaIVG6MESQ',
#   'channel_title': 'nigahiga',
#   'creation_date': '2006-07-21T01:40:43.000Z',
#   'country': 'US',
#   'view_count': 4147281205,
#   'comment_count': 0,
#   'subscriber_count': 21300000,
#   'video_count': 399},
#  {'Unnamed: 0': 56,
#   'channel_id': 'UClZuKq2m0Qu-HkopkSBLpEw',
#   'channel_title': 'Maluma',
#   'creation_date': '2018-03-23T22:14:33.000Z',
#   'country': 'Null',
#   'view_count': 275065440,
#   'comment_count': 0,
#   'subscriber_count': 22500000,
#   'video_count': 8},
#  {'Unnamed: 0': 57,
#   'channel_id': 'UCsPF3cApzCohxPp5oKdoWSQ',
#   'channel_title': 'CVS 3D Rhymes',
#   'creation_date': '2008-08-26T12:03:39.000Z',
#   'country': 'Null',
#   'view_count': 13156710674,
#   'comment_count': 0,
#   'subscriber_count': 22000000,
#   'video_count': 332},
#  {'Unnamed: 0': 58,
#   'channel_id': 'UCV9_KinVpV-snHe3C3n1hvA',
#   'channel_title': 'shane',
#   'creation_date': '2005-09-22T03:45:47.000Z',
#   'country': 'Null',
#   'view_count': 5367136080,
#   'comment_count': 0,
#   'subscriber_count': 23100000,
#   'video_count': 1696},
#  {'Unnamed: 0': 59,
#   'channel_id': 'UCANLZYMidaCbLQFWXBC95Jg',
#   'channel_title': 'TaylorSwiftVEVO',
#   'creation_date': '2009-05-12T05:29:33.000Z',
#   'country': 'US',
#   'view_count': 17828593602,
#   'comment_count': 0,
#   'subscriber_count': 27100000,
#   'video_count': 107},
#  {'Unnamed: 0': 60,
#   'channel_id': 'UCcdwLMPsaU2ezNSJU1nFoBQ',
#   'channel_title': "Pinkfong! Kids' Songs & Stories",
#   'creation_date': '2011-12-14T04:54:24.000Z',
#   'country': 'US',
#   'view_count': 10753653396,
#   'comment_count': 0,
#   'subscriber_count': 25800000,
#   'video_count': 1403},
#  {'Unnamed: 0': 61,
#   'channel_id': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#   'channel_title': 'MrBeast',
#   'creation_date': '2012-02-20T00:43:50.000Z',
#   'country': 'US',
#   'view_count': 3813526531,
#   'comment_count': 0,
#   'subscriber_count': 25800000,
#   'video_count': 712},
#  {'Unnamed: 0': 62,
#   'channel_id': 'UCYzPXprvl5Y-Sf0g4vX-m6g',
#   'channel_title': 'jacksepticeye',
#   'creation_date': '2007-02-24T14:28:56.000Z',
#   'country': 'IE',
#   'view_count': 11779038804,
#   'comment_count': 0,
#   'subscriber_count': 23000000,
#   'video_count': 4329},
#  {'Unnamed: 0': 63,
#   'channel_id': 'UCNUQK9mQoqi4yNXw2_Rj6SA',
#   'channel_title': 'GR6 EXPLODE',
#   'creation_date': '2014-08-05T05:21:03.000Z',
#   'country': 'BR',
#   'view_count': 12738349843,
#   'comment_count': 0,
#   'subscriber_count': 26400000,
#   'video_count': 2878},
#  {'Unnamed: 0': 64,
#   'channel_id': 'UCLkAepWjdylmXSltofFvsYQ',
#   'channel_title': 'BANGTANTV',
#   'creation_date': '2012-12-17T03:20:38.000Z',
#   'country': 'Null',
#   'view_count': 3151162696,
#   'comment_count': 0,
#   'subscriber_count': 23300000,
#   'video_count': 1084},
#  {'Unnamed: 0': 65,
#   'channel_id': 'UC55IWqFLDH1Xp7iu1_xknRA',
#   'channel_title': 'Colors TV',
#   'creation_date': '2008-06-13T11:09:32.000Z',
#   'country': 'IN',
#   'view_count': 15204763936,
#   'comment_count': 0,
#   'subscriber_count': 21100000,
#   'video_count': 33742},
#  {'Unnamed: 0': 66,
#   'channel_id': 'UCt4t-jeY85JegMlZ-E5UWtA',
#   'channel_title': 'Aaj Tak',
#   'creation_date': '2009-08-27T11:54:24.000Z',
#   'country': 'IN',
#   'view_count': 6354052625,
#   'comment_count': 0,
#   'subscriber_count': 23200000,
#   'video_count': 95073},
#  {'Unnamed: 0': 67,
#   'channel_id': 'UCM9r1xn6s30OnlJWb-jc3Sw',
#   'channel_title': 'XXXTENTACION',
#   'creation_date': '2015-06-23T01:27:37.000Z',
#   'country': 'US',
#   'view_count': 4378201684,
#   'comment_count': 0,
#   'subscriber_count': 22600000,
#   'video_count': 79},
#  {'Unnamed: 0': 68,
#   'channel_id': 'UC-yXuc1__OzjwpsJPlxYUCQ',
#   'channel_title': 'WORLDSTARHIPHOP',
#   'creation_date': '2008-11-08T13:30:04.000Z',
#   'country': 'US',
#   'view_count': 14265494805,
#   'comment_count': 0,
#   'subscriber_count': 22300000,
#   'video_count': 4516},
#  {'Unnamed: 0': 69,
#   'channel_id': 'UCJrDMFOdv1I2k8n9oK_V21w',
#   'channel_title': 'Tips Official',
#   'creation_date': '2007-05-22T10:13:28.000Z',
#   'country': 'IN',
#   'view_count': 10039056825,
#   'comment_count': 0,
#   'subscriber_count': 23500000,
#   'video_count': 2702},
#  {'Unnamed: 0': 70,
#   'channel_id': 'UC20vb-R_px4CguHzzBPhoyQ',
#   'channel_title': 'EminemVEVO',
#   'creation_date': '2009-05-12T05:27:52.000Z',
#   'country': 'Null',
#   'view_count': 13895993915,
#   'comment_count': 0,
#   'subscriber_count': 26000000,
#   'video_count': 84},
#  {'Unnamed: 0': 71,
#   'channel_id': 'UChGJGhZ9SOOHvBB0Y4DOO_w',
#   'channel_title': "Ryan's World",
#   'creation_date': '2015-03-17T00:18:47.000Z',
#   'country': 'US',
#   'view_count': 33702183780,
#   'comment_count': 0,
#   'subscriber_count': 22500000,
#   'video_count': 1563},
#  {'Unnamed: 0': 72,
#   'channel_id': 'UCiGm_E4ZwYSHV3bcW1pnSeQ',
#   'channel_title': 'Billie Eilish',
#   'creation_date': '2013-02-06T23:21:04.000Z',
#   'country': 'US',
#   'view_count': 492129978,
#   'comment_count': 0,
#   'subscriber_count': 22300000,
#   'video_count': 24},
#  {'Unnamed: 0': 73,
#   'channel_id': 'UC6-F5tO8uklgE9Zy8IvbdFw',
#   'channel_title': 'SAB TV',
#   'creation_date': '2007-08-04T16:05:01.000Z',
#   'country': 'IN',
#   'view_count': 23400203766,
#   'comment_count': 0,
#   'subscriber_count': 25300000,
#   'video_count': 26404},
#  {'Unnamed: 0': 74,
#   'channel_id': 'UCoGDh1Xa3kUCpok24JN5DKA',
#   'channel_title': 'enchufetv',
#   'creation_date': '2011-11-13T01:33:03.000Z',
#   'country': 'Null',
#   'view_count': 7777551143,
#   'comment_count': 0,
#   'subscriber_count': 21800000,
#   'video_count': 1241},
#  {'Unnamed: 0': 75,
#   'channel_id': 'UCsT0YIqwnpJCM-mx7-gSA4Q',
#   'channel_title': 'TEDx Talks',
#   'creation_date': '2009-06-23T16:00:48.000Z',
#   'country': 'Null',
#   'view_count': 3900437230,
#   'comment_count': 0,
#   'subscriber_count': 21700000,
#   'video_count': 144491},
#  {'Unnamed: 0': 76,
#   'channel_id': 'UC3ZkCd7XtUREnjjt3cyY_gg',
#   'channel_title': 'WorkpointOfficial',
#   'creation_date': '2012-11-05T04:27:20.000Z',
#   'country': 'TH',
#   'view_count': 22122461169,
#   'comment_count': 0,
#   'subscriber_count': 26200000,
#   'video_count': 38333},
#  {'Unnamed: 0': 77,
#   'channel_id': 'UCbTVTephX30ZhQF5zwFppBg',
#   'channel_title': 'rezendeevil',
#   'creation_date': '2012-02-12T23:58:25.000Z',
#   'country': 'BR',
#   'view_count': 9148413742,
#   'comment_count': 0,
#   'subscriber_count': 25200000,
#   'video_count': 8233},
#  {'Unnamed: 0': 78,
#   'channel_id': 'UCAW-NpUFkMyCNrvRSSGIvDQ',
#   'channel_title': 'Ninja',
#   'creation_date': '2011-11-11T06:17:51.000Z',
#   'country': 'US',
#   'view_count': 1982179672,
#   'comment_count': 0,
#   'subscriber_count': 22400000,
#   'video_count': 969},
#  {'Unnamed: 0': 79,
#   'channel_id': 'UCs8qka8tfhdc69wzXYdtZ3A',
#   'channel_title': 'LosPolinesios',
#   'creation_date': '2012-12-16T21:39:34.000Z',
#   'country': 'Null',
#   'view_count': 4266731546,
#   'comment_count': 0,
#   'subscriber_count': 20800000,
#   'video_count': 496},
#  {'Unnamed: 0': 80,
#   'channel_id': 'UCS94J1s6-qc8v7btCdS2pNg',
#   'channel_title': 'Stacy Toys',
#   'creation_date': '2017-11-14T14:56:43.000Z',
#   'country': 'US',
#   'view_count': 7388471573,
#   'comment_count': 0,
#   'subscriber_count': 21800000,
#   'video_count': 240},
#  {'Unnamed: 0': 81,
#   'channel_id': 'UC1l7wYrva1qCH-wgqcHaaRg',
#   'channel_title': 'David Guetta',
#   'creation_date': '2009-12-11T07:02:52.000Z',
#   'country': 'Null',
#   'view_count': 11958005638,
#   'comment_count': 0,
#   'subscriber_count': 20900000,
#   'video_count': 525},
#  {'Unnamed: 0': 82,
#   'channel_id': 'UCbTLwN10NoCU4WDzLf1JMOA',
#   'channel_title': 'YRF',
#   'creation_date': '2006-06-07T23:07:50.000Z',
#   'country': 'IN',
#   'view_count': 13353473226,
#   'comment_count': 0,
#   'subscriber_count': 25200000,
#   'video_count': 3740},
#  {'Unnamed: 0': 83,
#   'channel_id': 'UC_gV70G_Y51LTa3qhu8KiEA',
#   'channel_title': 'LUCCAS NETO - LUCCAS TOON',
#   'creation_date': '2014-07-31T04:07:52.000Z',
#   'country': 'BR',
#   'view_count': 7879827935,
#   'comment_count': 0,
#   'subscriber_count': 27200000,
#   'video_count': 751},
#  {'Unnamed: 0': 84,
#   'channel_id': 'UC7_YxT-KID8kRbqZo7MyscQ',
#   'channel_title': 'Markiplier',
#   'creation_date': '2012-05-26T20:30:52.000Z',
#   'country': 'US',
#   'view_count': 11995263825,
#   'comment_count': 0,
#   'subscriber_count': 24600000,
#   'video_count': 4536},
#  {'Unnamed: 0': 85,
#   'channel_id': 'UCS5Oz6CHmeoF7vSad0qqXfw',
#   'channel_title': 'DanTDM',
#   'creation_date': '2012-07-14T21:58:18.000Z',
#   'country': 'GB',
#   'view_count': 15773480716,
#   'comment_count': 0,
#   'subscriber_count': 22300000,
#   'video_count': 3268},
#  {'Unnamed: 0': 86,
#   'channel_id': 'UCY30JRSgfhYXA6i6xX1erWg',
#   'channel_title': 'Smosh',
#   'creation_date': '2005-11-19T10:25:07.000Z',
#   'country': 'US',
#   'view_count': 9062885920,
#   'comment_count': 0,
#   'subscriber_count': 25000000,
#   'video_count': 1085},
#  {'Unnamed: 0': 87,
#   'channel_id': 'UCX52tYZiEh_mHoFja3Veciw',
#   'channel_title': 'Eros Now',
#   'creation_date': '2007-02-27T20:07:38.000Z',
#   'country': 'Null',
#   'view_count': 12182576985,
#   'comment_count': 0,
#   'subscriber_count': 20900000,
#   'video_count': 10093},
#  {'Unnamed: 0': 88,
#   'channel_id': 'UCoUM-UJ7rirJYP8CQ0EIaHA',
#   'channel_title': 'Bruno Mars',
#   'creation_date': '2006-09-19T01:34:43.000Z',
#   'country': 'Null',
#   'view_count': 11226266772,
#   'comment_count': 0,
#   'subscriber_count': 26000000,
#   'video_count': 67},
#  {'Unnamed: 0': 89,
#   'channel_id': 'UCKqH_9mk1waLgBiL2vT5b9g',
#   'channel_title': 'VanossGaming',
#   'creation_date': '2011-09-15T07:05:29.000Z',
#   'country': 'Null',
#   'view_count': 11774725127,
#   'comment_count': 0,
#   'subscriber_count': 24900000,
#   'video_count': 1082},
#  {'Unnamed: 0': 90,
#   'channel_id': 'UCpDJl2EmP7Oh90Vylx0dZtA',
#   'channel_title': "Spinnin' Records",
#   'creation_date': '2007-07-12T12:23:44.000Z',
#   'country': 'NL',
#   'view_count': 15522310789,
#   'comment_count': 0,
#   'subscriber_count': 26200000,
#   'video_count': 9215},
#  {'Unnamed: 0': 91,
#   'channel_id': 'UC-8Q-hLdECwQmaWNwXitYDw',
#   'channel_title': 'KatyPerryVEVO',
#   'creation_date': '2009-12-13T03:04:53.000Z',
#   'country': 'US',
#   'view_count': 18376186831,
#   'comment_count': 0,
#   'subscriber_count': 25900000,
#   'video_count': 136},
#  {'Unnamed: 0': 92,
#   'channel_id': 'UC_aEa8K-EOJ3D6gOs7HcyNg',
#   'channel_title': 'NoCopyrightSounds',
#   'creation_date': '2011-08-14T20:13:26.000Z',
#   'country': 'GB',
#   'view_count': 6927490433,
#   'comment_count': 0,
#   'subscriber_count': 24000000,
#   'video_count': 682},
#  {'Unnamed: 0': 93,
#   'channel_id': 'UCjIA3wwhi0QjSOXAZwOXbPA',
#   'channel_title': 'Ozuna',
#   'creation_date': '2016-03-24T19:55:58.000Z',
#   'country': 'PR',
#   'view_count': 12750143707,
#   'comment_count': 0,
#   'subscriber_count': 26400000,
#   'video_count': 70},
#  {'Unnamed: 0': 94,
#   'channel_id': 'UCVtFOytbRpEvzLjvqGG5gxQ',
#   'channel_title': 'KSI',
#   'creation_date': '2009-07-25T01:11:42.000Z',
#   'country': 'GB',
#   'view_count': 5038835144,
#   'comment_count': 0,
#   'subscriber_count': 20700000,
#   'video_count': 1203},
#  {'Unnamed: 0': 95,
#   'channel_id': 'UC2xskkQVFEpLcGFnNSLQY0A',
#   'channel_title': 'RihannaVEVO',
#   'creation_date': '2009-05-12T05:29:11.000Z',
#   'country': 'US',
#   'view_count': 14596703501,
#   'comment_count': 0,
#   'subscriber_count': 26000000,
#   'video_count': 106},
#  {'Unnamed: 0': 96,
#   'channel_id': 'UCbrd1vu4_7qIE6IPV_dA-OA',
#   'channel_title': 'GENIAL',
#   'creation_date': '2017-06-01T07:07:20.000Z',
#   'country': 'Null',
#   'view_count': 3092260923,
#   'comment_count': 0,
#   'subscriber_count': 20600000,
#   'video_count': 2689},
#  {'Unnamed: 0': 97,
#   'channel_id': 'UC4rasfm9J-X4jNl9SvXp8xA',
#   'channel_title': 'Ultra Music',
#   'creation_date': '2006-10-24T20:03:16.000Z',
#   'country': 'Null',
#   'view_count': 11457082557,
#   'comment_count': 0,
#   'subscriber_count': 20200000,
#   'video_count': 3875},
#  {'Unnamed: 0': 98,
#   'channel_id': 'UCQZfFRohQ7UX-0CdXl-6pwQ',
#   'channel_title': 'Kimberly Loaiza',
#   'creation_date': '2016-11-16T03:28:16.000Z',
#   'country': 'MX',
#   'view_count': 1359881375,
#   'comment_count': 0,
#   'subscriber_count': 20200000,
#   'video_count': 102},
#  {'Unnamed: 0': 99,
#   'channel_id': 'UCT9zcQNlyht7fRlcjmflRSA',
#   'channel_title': 'ImagineDragons',
#   'creation_date': '2009-08-03T09:09:31.000Z',
#   'country': 'Null',
#   'view_count': 19726921,
#   'comment_count': 0,
#   'subscriber_count': 20200000,
#   'video_count': 51},
#  {'Unnamed: 0': 100,
#   'channel_id': 'UCEf_Bc-KVd7onSeifS3py9g',
#   'channel_title': 'SMTOWN',
#   'creation_date': '2006-03-18T15:43:10.000Z',
#   'country': 'Null',
#   'view_count': 15523556640,
#   'comment_count': 0,
#   'subscriber_count': 20400000,
#   'video_count': 3922},
#  {'Unnamed: 0': 101,
#   'channel_id': 'UCWwWOFsW68TqXE-HZLC3WIA',
#   'channel_title': 'The ACE Family',
#   'creation_date': '2016-01-10T20:46:31.000Z',
#   'country': 'Null',
#   'view_count': 3218459617,
#   'comment_count': 0,
#   'subscriber_count': 17700000,
#   'video_count': 477},
#  {'Unnamed: 0': 102,
#   'channel_id': 'UC8f7MkX4MFOOJ2SerXLInCA',
#   'channel_title': 'one31',
#   'creation_date': '2013-01-10T12:27:39.000Z',
#   'country': 'TH',
#   'view_count': 14885008186,
#   'comment_count': 0,
#   'subscriber_count': 19600000,
#   'video_count': 76221},
#  {'Unnamed: 0': 103,
#   'channel_id': 'UCyQqzYXQBUWgBTn4pw_fFSQ',
#   'channel_title': 'AuronPlay',
#   'creation_date': '2006-02-28T16:12:01.000Z',
#   'country': 'ES',
#   'view_count': 2460209588,
#   'comment_count': 0,
#   'subscriber_count': 18900000,
#   'video_count': 396},
#  {'Unnamed: 0': 104,
#   'channel_id': 'UCcYrdFJF7hmPXRNaWdrko4w',
#   'channel_title': 'ChrisBrownTV',
#   'creation_date': '2006-12-20T18:54:54.000Z',
#   'country': 'Null',
#   'view_count': 33637686,
#   'comment_count': 0,
#   'subscriber_count': 17900000,
#   'video_count': 18},
#  {'Unnamed: 0': 105,
#   'channel_id': 'UCF1JIbMUs6uqoZEY1Haw0GQ',
#   'channel_title': 'Shemaroo',
#   'creation_date': '2007-09-01T11:44:51.000Z',
#   'country': 'IN',
#   'view_count': 9922390273,
#   'comment_count': 0,
#   'subscriber_count': 19800000,
#   'video_count': 6878},
#  {'Unnamed: 0': 106,
#   'channel_id': 'UCNYW2vfGrUE6R5mIJYzkRyQ',
#   'channel_title': 'DrossRotzank',
#   'creation_date': '2006-03-09T20:06:26.000Z',
#   'country': 'AR',
#   'view_count': 4041069436,
#   'comment_count': 0,
#   'subscriber_count': 18100000,
#   'video_count': 1281},
#  {'Unnamed: 0': 107,
#   'channel_id': 'UCwD4x63A9KC7Si2RuSfg-SA',
#   'channel_title': 'Lucas and Marcus',
#   'creation_date': '2011-01-19T22:44:47.000Z',
#   'country': 'US',
#   'view_count': 4453848393,
#   'comment_count': 0,
#   'subscriber_count': 17900000,
#   'video_count': 519},
#  {'Unnamed: 0': 108,
#   'channel_id': 'UCPHXtOVmjvbP9OJihsd7gCg',
#   'channel_title': 'CanalCanalha',
#   'creation_date': '2011-04-08T00:19:27.000Z',
#   'country': 'Null',
#   'view_count': 1392889788,
#   'comment_count': 0,
#   'subscriber_count': 19000000,
#   'video_count': 223},
#  {'Unnamed: 0': 111,
#   'channel_id': 'UCtW7qWjpCZ8zps-Cf2NF26w',
#   'channel_title': 'Gaane Sune Ansune',
#   'creation_date': '2015-08-24T08:17:50.000Z',
#   'country': 'IN',
#   'view_count': 7698175222,
#   'comment_count': 0,
#   'subscriber_count': 18300000,
#   'video_count': 2249},
#  {'Unnamed: 0': 112,
#   'channel_id': 'UCaKLg1ELiX0zTJ6Je3c5esA',
#   'channel_title': 'Atta Halilintar',
#   'creation_date': '2014-01-26T16:19:24.000Z',
#   'country': 'ID',
#   'view_count': 1818928480,
#   'comment_count': 0,
#   'subscriber_count': 19800000,
#   'video_count': 646},
#  {'Unnamed: 0': 113,
#   'channel_id': 'UC3jOd7GUMhpgJRBhiLzuLsg',
#   'channel_title': 'Nicki Minaj',
#   'creation_date': '2013-08-28T15:19:24.000Z',
#   'country': 'US',
#   'view_count': 91881891,
#   'comment_count': 0,
#   'subscriber_count': 19900000,
#   'video_count': 20},
#  {'Unnamed: 0': 114,
#   'channel_id': 'UCVp3nfGRxmMadNDuVbJSk8A',
#   'channel_title': 'Wiz Khalifa',
#   'creation_date': '2008-05-09T02:49:21.000Z',
#   'country': 'Null',
#   'view_count': 9245178170,
#   'comment_count': 0,
#   'subscriber_count': 19700000,
#   'video_count': 474},
#  {'Unnamed: 0': 115,
#   'channel_id': 'UCByOQJjav0CUDwxCk-jVNRQ',
#   'channel_title': 'Drake',
#   'creation_date': '2009-06-05T23:20:21.000Z',
#   'country': 'Null',
#   'view_count': 333416505,
#   'comment_count': 0,
#   'subscriber_count': 19200000,
#   'video_count': 48},
#  {'Unnamed: 0': 117,
#   'channel_id': 'UC7TTtOQKMXTWWMtWQMIgVSA',
#   'channel_title': 'Collins Key',
#   'creation_date': '2011-08-09T18:02:53.000Z',
#   'country': 'US',
#   'view_count': 4096593817,
#   'comment_count': 0,
#   'subscriber_count': 19800000,
#   'video_count': 241},
#  {'Unnamed: 0': 118,
#   'channel_id': 'UC_TVqp_SyG6j5hG-xVRy95A',
#   'channel_title': 'Skrillex',
#   'creation_date': '2010-04-06T19:44:30.000Z',
#   'country': 'Null',
#   'view_count': 5237076896,
#   'comment_count': 0,
#   'subscriber_count': 19000000,
#   'video_count': 168},
#  {'Unnamed: 0': 119,
#   'channel_id': 'UCBAb_DK4GYZqZR9MFA7y2Xg',
#   'channel_title': 'Galinha Pintadinha',
#   'creation_date': '2006-08-30T19:30:30.000Z',
#   'country': 'BR',
#   'view_count': 13412745114,
#   'comment_count': 0,
#   'subscriber_count': 19300000,
#   'video_count': 50},
#  {'Unnamed: 0': 120,
#   'channel_id': 'UCcvNYxWXR_5TjVK7cSCdW-g',
#   'channel_title': 'T-Series Apna Punjab',
#   'creation_date': '2011-09-26T11:44:33.000Z',
#   'country': 'IN',
#   'view_count': 9847435517,
#   'comment_count': 0,
#   'subscriber_count': 19500000,
#   'video_count': 4437},
#  {'Unnamed: 0': 121,
#   'channel_id': 'UCLsooMJoIpl_7ux2jvdPB-Q',
#   'channel_title': 'Super Simple Songs - Kids Songs',
#   'creation_date': '2006-09-08T08:50:54.000Z',
#   'country': 'CA',
#   'view_count': 16586572830,
#   'comment_count': 0,
#   'subscriber_count': 18900000,
#   'video_count': 477},
#  {'Unnamed: 0': 123,
#   'channel_id': 'UCLp8RBhQHu9wSsq62j_Md6A',
#   'channel_title': 'LuisFonsiVEVO',
#   'creation_date': '2009-05-12T05:28:36.000Z',
#   'country': 'US',
#   'view_count': 11532041553,
#   'comment_count': 0,
#   'subscriber_count': 18000000,
#   'video_count': 68},
#  {'Unnamed: 0': 124,
#   'channel_id': 'UCcgVECVN4OKV6DH1jLkqmcA',
#   'channel_title': 'Jake Paul',
#   'creation_date': '2013-09-19T19:31:16.000Z',
#   'country': 'Null',
#   'view_count': 6269826954,
#   'comment_count': 0,
#   'subscriber_count': 19700000,
#   'video_count': 836},
#  {'Unnamed: 0': 125,
#   'channel_id': 'UCmL1WlDI8UkXDXCXcBQN9CA',
#   'channel_title': 'Ultra Bollywood',
#   'creation_date': '2009-10-21T12:28:20.000Z',
#   'country': 'Null',
#   'view_count': 10714116591,
#   'comment_count': 0,
#   'subscriber_count': 19400000,
#   'video_count': 10395},
#  {'Unnamed: 0': 126,
#   'channel_id': 'UCxSz6JVYmzVhtkraHWZC7HQ',
#   'channel_title': 'Liza Koshy',
#   'creation_date': '2013-09-02T22:55:05.000Z',
#   'country': 'US',
#   'view_count': 2301078981,
#   'comment_count': 0,
#   'subscriber_count': 17700000,
#   'video_count': 166},
#  {'Unnamed: 0': 127,
#   'channel_id': 'UC2pmfLm7iq6Ov1UwYrWYkZA',
#   'channel_title': 'Vevo',
#   'creation_date': '2006-04-14T17:07:29.000Z',
#   'country': 'Null',
#   'view_count': 560628465,
#   'comment_count': 0,
#   'subscriber_count': 19000000,
#   'video_count': 1558},
#  {'Unnamed: 0': 128,
#   'channel_id': 'UC48h7Dst_hX82HxOf3xJw_w',
#   'channel_title': 'Ch3Thailand',
#   'creation_date': '2014-05-29T07:24:43.000Z',
#   'country': 'TH',
#   'view_count': 14402190534,
#   'comment_count': 0,
#   'subscriber_count': 19900000,
#   'video_count': 66012},
#  {'Unnamed: 0': 129,
#   'channel_id': 'UCpb_iJuhFe8V6rQdbNqfAlQ',
#   'channel_title': 'NickyJamTV',
#   'creation_date': '2012-01-10T23:16:13.000Z',
#   'country': 'Null',
#   'view_count': 12393510406,
#   'comment_count': 0,
#   'subscriber_count': 19600000,
#   'video_count': 243},
#  {'Unnamed: 0': 130,
#   'channel_id': 'UC1ciY6kR3yj3kaKZ6R7ewAg',
#   'channel_title': 'Infobells - Hindi',
#   'creation_date': '2014-06-06T15:24:36.000Z',
#   'country': 'IN',
#   'view_count': 8862583867,
#   'comment_count': 0,
#   'subscriber_count': 18000000,
#   'video_count': 288},
#  {'Unnamed: 0': 132,
#   'channel_id': 'UCGnjeahCJW1AF34HBmQTJ-Q',
#   'channel_title': 'shakiraVEVO',
#   'creation_date': '2009-09-02T23:38:38.000Z',
#   'country': 'Null',
#   'view_count': 16859629103,
#   'comment_count': 0,
#   'subscriber_count': 19100000,
#   'video_count': 164},
#  {'Unnamed: 0': 133,
#   'channel_id': 'UCpko_-a4wgz2u_DgDgd9fqA',
#   'channel_title': 'BuzzFeedVideo',
#   'creation_date': '2011-08-10T21:27:29.000Z',
#   'country': 'Null',
#   'view_count': 16055213500,
#   'comment_count': 0,
#   'subscriber_count': 19600000,
#   'video_count': 6454},
#  {'Unnamed: 0': 136,
#   'channel_id': 'UC9gFih9rw0zNCK3ZtoKQQyA',
#   'channel_title': 'JennaMarbles',
#   'creation_date': '2010-02-16T17:38:20.000Z',
#   'country': 'Null',
#   'view_count': 3379815697,
#   'comment_count': 0,
#   'subscriber_count': 20000000,
#   'video_count': 475},
#  {'Unnamed: 0': 137,
#   'channel_id': 'UCmBA_wu8xGg1OfOkfW13Q0Q',
#   'channel_title': 'Bad Bunny',
#   'creation_date': '2014-06-09T02:50:42.000Z',
#   'country': 'PR',
#   'view_count': 5725562126,
#   'comment_count': 0,
#   'subscriber_count': 20000000,
#   'video_count': 33},
#  {'Unnamed: 0': 139,
#   'channel_id': 'UCIPA6iWNaoetaa1T46RkzXw',
#   'channel_title': 'AuthenticGames',
#   'creation_date': '2011-10-07T01:50:49.000Z',
#   'country': 'BR',
#   'view_count': 7321075366,
#   'comment_count': 0,
#   'subscriber_count': 17800000,
#   'video_count': 3796},
#  {'Unnamed: 0': 140,
#   'channel_id': 'UC0v-tlzsn0QZwJnkiaUSJVQ',
#   'channel_title': 'FBE',
#   'creation_date': '2007-06-04T09:55:54.000Z',
#   'country': 'US',
#   'view_count': 8477637335,
#   'comment_count': 0,
#   'subscriber_count': 19700000,
#   'video_count': 2125},
#  {'Unnamed: 0': 141,
#   'channel_id': 'UCq3Ci-h945sbEYXpVlw7rJg',
#   'channel_title': 'The Chainsmokers',
#   'creation_date': '2012-09-22T20:02:38.000Z',
#   'country': 'US',
#   'view_count': 797562272,
#   'comment_count': 0,
#   'subscriber_count': 19800000,
#   'video_count': 192},
#  {'Unnamed: 0': 143,
#   'channel_id': 'UCw8ZhLPdQ0u_Y-TLKd61hGA',
#   'channel_title': '1MILLION Dance Studio',
#   'creation_date': '2015-02-06T09:32:21.000Z',
#   'country': 'KR',
#   'view_count': 4390571400,
#   'comment_count': 0,
#   'subscriber_count': 18400000,
#   'video_count': 1737},
#  {'Unnamed: 0': 145,
#   'channel_id': 'UC0VOyT2OCBKdQhF3BAbZ-1g',
#   'channel_title': 'ArianaGrandeVevo',
#   'creation_date': '2010-10-21T23:38:49.000Z',
#   'country': 'Null',
#   'view_count': 13088521518,
#   'comment_count': 0,
#   'subscriber_count': 18600000,
#   'video_count': 110},
#  {'Unnamed: 0': 148,
#   'channel_id': 'UCG8rbF3g2AMX70yOd8vqIZg',
#   'channel_title': 'Logan Paul',
#   'creation_date': '2015-08-29T03:28:33.000Z',
#   'country': 'US',
#   'view_count': 4759873133,
#   'comment_count': 0,
#   'subscriber_count': 20000000,
#   'video_count': 654},
#  {'Unnamed: 0': 151,
#   'channel_id': 'UCUY6t_N9MyEWu6I0ZXkbtKA',
#   'channel_title': 'Las Ratitas',
#   'creation_date': '2015-10-18T10:56:30.000Z',
#   'country': 'ES',
#   'view_count': 5560764256,
#   'comment_count': 0,
#   'subscriber_count': 17500000,
#   'video_count': 153},
#  {'Unnamed: 0': 152,
#   'channel_id': 'UClZF7OsrECe3t_ADrjZEh_Q',
#   'channel_title': 'Geet MP3',
#   'creation_date': '2016-10-22T03:37:32.000Z',
#   'country': 'IN',
#   'view_count': 4402668420,
#   'comment_count': 0,
#   'subscriber_count': 16300000,
#   'video_count': 264},
#  {'Unnamed: 0': 153,
#   'channel_id': 'UCYVinkwSX7szARULgYpvhLw',
#   'channel_title': 'Ali-A',
#   'creation_date': '2006-09-13T17:12:04.000Z',
#   'country': 'GB',
#   'view_count': 4785452302,
#   'comment_count': 0,
#   'subscriber_count': 16500000,
#   'video_count': 3306},
#  {'Unnamed: 0': 154,
#   'channel_id': 'UCGRtuAmEObNSmlOLDWzZfVg',
#   'channel_title': 'Caeli',
#   'creation_date': '2010-09-22T15:51:25.000Z',
#   'country': 'Null',
#   'view_count': 1464309338,
#   'comment_count': 0,
#   'subscriber_count': 16100000,
#   'video_count': 518},
#  {'Unnamed: 0': 155,
#   'channel_id': 'UCN9HPn2fq-NL8M5_kp4RWZQ',
#   'channel_title': 'Sia',
#   'creation_date': '2007-11-19T18:43:20.000Z',
#   'country': 'Null',
#   'view_count': 224205855,
#   'comment_count': 0,
#   'subscriber_count': 16100000,
#   'video_count': 62},
#  {'Unnamed: 0': 156,
#   'channel_id': 'UCa6vGFO9ty8v5KZJXQxdhaw',
#   'channel_title': 'Jimmy Kimmel Live',
#   'creation_date': '2006-09-20T06:18:26.000Z',
#   'country': 'US',
#   'view_count': 8731043246,
#   'comment_count': 0,
#   'subscriber_count': 15500000,
#   'video_count': 4408},
#  {'Unnamed: 0': 157,
#   'channel_id': 'UCzoUWqjCbcfWFdOMvoep8FA',
#   'channel_title': 'Juan De Dios Pantoja',
#   'creation_date': '2014-06-09T18:02:23.000Z',
#   'country': 'MX',
#   'view_count': 1352721220,
#   'comment_count': 0,
#   'subscriber_count': 17400000,
#   'video_count': 181},
#  {'Unnamed: 0': 158,
#   'channel_id': 'UCeLHszkByNZtPKcaVXOCOQQ',
#   'channel_title': 'Post Malone',
#   'creation_date': '2011-12-15T00:40:53.000Z',
#   'country': 'US',
#   'view_count': 1399240517,
#   'comment_count': 0,
#   'subscriber_count': 15900000,
#   'video_count': 30},
#  {'Unnamed: 0': 159,
#   'channel_id': 'UCwppdrjsBPAZg5_cUwQjfMQ',
#   'channel_title': 'Charlie Puth',
#   'creation_date': '2009-09-09T21:32:32.000Z',
#   'country': 'US',
#   'view_count': 6079727158,
#   'comment_count': 0,
#   'subscriber_count': 15800000,
#   'video_count': 85},
#  {'Unnamed: 0': 160,
#   'channel_id': 'UCucot-Zp428OwkyRm2I7v2Q',
#   'channel_title': 'James Charles',
#   'creation_date': '2015-12-01T22:04:43.000Z',
#   'country': 'US',
#   'view_count': 1777568159,
#   'comment_count': 0,
#   'subscriber_count': 16300000,
#   'video_count': 240},
#  {'Unnamed: 0': 161,
#   'channel_id': 'UCpB959t8iPrxQWj7G6n0ctQ',
#   'channel_title': 'SSSniperWolf',
#   'creation_date': '2013-01-20T06:26:02.000Z',
#   'country': 'US',
#   'view_count': 4401696632,
#   'comment_count': 0,
#   'subscriber_count': 17300000,
#   'video_count': 2148},
#  {'Unnamed: 0': 162,
#   'channel_id': 'UCzVIrPfZBE-XkBISBybMBLA',
#   'channel_title': 'Werevertumorro',
#   'creation_date': '2007-02-28T02:25:20.000Z',
#   'country': 'Null',
#   'view_count': 2669325674,
#   'comment_count': 0,
#   'subscriber_count': 16500000,
#   'video_count': 1045},
#  {'Unnamed: 0': 163,
#   'channel_id': 'UC6pjHMC4QXMi4llCCjtDXWg',
#   'channel_title': 'Lil pump',
#   'creation_date': '2015-10-15T22:04:28.000Z',
#   'country': 'Null',
#   'view_count': 3272316879,
#   'comment_count': 0,
#   'subscriber_count': 16300000,
#   'video_count': 42},
#  {'Unnamed: 0': 164,
#   'channel_id': 'UCG9gfnA5UDoLvz-tC9B-HKw',
#   'channel_title': 'GMM GRAMMY OFFICIAL',
#   'creation_date': '2010-11-08T03:39:50.000Z',
#   'country': 'TH',
#   'view_count': 16658452641,
#   'comment_count': 0,
#   'subscriber_count': 17100000,
#   'video_count': 7106},
#  {'Unnamed: 0': 165,
#   'channel_id': 'UC0ebPa2q1rwZVN7dYemunUQ',
#   'channel_title': 'Erlania e Valentina Pontes',
#   'creation_date': '2014-04-14T03:10:28.000Z',
#   'country': 'BR',
#   'view_count': 4552177113,
#   'comment_count': 0,
#   'subscriber_count': 16200000,
#   'video_count': 726},
#  {'Unnamed: 0': 166,
#   'channel_id': 'UCy7whoHQXzhYxp9AQmrPFVw',
#   'channel_title': 'Totoykids',
#   'creation_date': '2014-12-02T20:35:42.000Z',
#   'country': 'BR',
#   'view_count': 7030980517,
#   'comment_count': 0,
#   'subscriber_count': 15600000,
#   'video_count': 770},
#  {'Unnamed: 0': 167,
#   'channel_id': 'UCgwv23FVv3lqh567yagXfNg',
#   'channel_title': 'DisneyMusicVEVO',
#   'creation_date': '2010-05-20T13:09:24.000Z',
#   'country': 'Null',
#   'view_count': 10085022663,
#   'comment_count': 0,
#   'subscriber_count': 16400000,
#   'video_count': 998},
#  {'Unnamed: 0': 168,
#   'channel_id': 'UCpGdL9Sn3Q5YWUH2DVUW1Ug',
#   'channel_title': 'PopularMMOs',
#   'creation_date': '2012-04-17T17:18:29.000Z',
#   'country': 'Null',
#   'view_count': 13451573780,
#   'comment_count': 0,
#   'subscriber_count': 16900000,
#   'video_count': 4533},
#  {'Unnamed: 0': 169,
#   'channel_id': 'UCEWHPFNilsT0IfQfutVzsag',
#   'channel_title': 'Porta dos Fundos',
#   'creation_date': '2012-03-12T04:30:27.000Z',
#   'country': 'BR',
#   'view_count': 5345585034,
#   'comment_count': 0,
#   'subscriber_count': 16200000,
#   'video_count': 1249},
#  {'Unnamed: 0': 170,
#   'channel_id': 'UC57XAjJ04TY8gNxOWf-Sy0Q',
#   'channel_title': '5-Minute Crafts KIDS',
#   'creation_date': '2017-10-30T13:03:19.000Z',
#   'country': 'US',
#   'view_count': 3250461878,
#   'comment_count': 0,
#   'subscriber_count': 15800000,
#   'video_count': 2207},
#  {'Unnamed: 0': 171,
#   'channel_id': 'UC4LHNX8d8RqnDX0OezgmCTg',
#   'channel_title': 'TheWillyrex',
#   'creation_date': '2011-01-26T13:28:11.000Z',
#   'country': 'ES',
#   'view_count': 5740921953,
#   'comment_count': 0,
#   'subscriber_count': 16000000,
#   'video_count': 5629},
#  {'Unnamed: 0': 172,
#   'channel_id': 'UCkvK_5omS-42Ovgah8KRKtg',
#   'channel_title': 'jeffreestar',
#   'creation_date': '2006-02-14T22:18:44.000Z',
#   'country': 'US',
#   'view_count': 1975574984,
#   'comment_count': 0,
#   'subscriber_count': 16500000,
#   'video_count': 358},
#  {'Unnamed: 0': 173,
#   'channel_id': 'UCgFXm4TI8htWmCyJ6cVPG_A',
#   'channel_title': 'Toys and Colors',
#   'creation_date': '2016-03-17T20:35:54.000Z',
#   'country': 'US',
#   'view_count': 11008662065,
#   'comment_count': 0,
#   'subscriber_count': 16600000,
#   'video_count': 340},
#  {'Unnamed: 0': 174,
#   'channel_id': 'UCEKWXRsfUHkan-D_ljU8Asw',
#   'channel_title': 'Rajshri',
#   'creation_date': '2006-03-24T03:45:24.000Z',
#   'country': 'IN',
#   'view_count': 9024567018,
#   'comment_count': 0,
#   'subscriber_count': 17100000,
#   'video_count': 5614},
#  {'Unnamed: 0': 175,
#   'channel_id': 'UC2etEuPIfohP4P53wM0KImA',
#   'channel_title': '5-Minute Crafts GIRLY',
#   'creation_date': '2018-01-18T08:58:56.000Z',
#   'country': 'US',
#   'view_count': 2984553137,
#   'comment_count': 0,
#   'subscriber_count': 16800000,
#   'video_count': 1978},
#  {'Unnamed: 0': 176,
#   'channel_id': 'UC4tS4Q_Cno5JVcIUXxQOOpA',
#   'channel_title': 'Ricis Official',
#   'creation_date': '2016-01-15T15:57:39.000Z',
#   'country': 'ID',
#   'view_count': 2145326650,
#   'comment_count': 0,
#   'subscriber_count': 17500000,
#   'video_count': 731},
#  {'Unnamed: 0': 177,
#   'channel_id': 'UCJFp8uSYCjXOMnkUyb3CQ3Q',
#   'channel_title': 'Tasty',
#   'creation_date': '2016-01-22T23:05:31.000Z',
#   'country': 'US',
#   'view_count': 3577781101,
#   'comment_count': 0,
#   'subscriber_count': 16600000,
#   'video_count': 3471},
#  {'Unnamed: 0': 178,
#   'channel_id': 'UCmv1CLT6ZcFdTJMHxaR9XeA',
#   'channel_title': 'PTXofficial',
#   'creation_date': '2011-09-10T17:09:59.000Z',
#   'country': 'Null',
#   'view_count': 4139301204,
#   'comment_count': 0,
#   'subscriber_count': 17300000,
#   'video_count': 205},
#  {'Unnamed: 0': 179,
#   'channel_id': 'UCWwqHwqLSrdWMgp5DZG5Dzg',
#   'channel_title': 'Troom Troom',
#   'creation_date': '2015-09-12T13:49:04.000Z',
#   'country': 'US',
#   'view_count': 5348145034,
#   'comment_count': 0,
#   'subscriber_count': 15900000,
#   'video_count': 1069},
#  {'Unnamed: 0': 180,
#   'channel_id': 'UComP_epzeKzvBX156r6pm1Q',
#   'channel_title': 'AdeleVEVO',
#   'creation_date': '2009-10-15T19:07:17.000Z',
#   'country': 'Null',
#   'view_count': 8499307833,
#   'comment_count': 0,
#   'subscriber_count': 15800000,
#   'video_count': 31},
#  {'Unnamed: 0': 181,
#   'channel_id': 'UCRWFSbif-RFENbBrSiez1DA',
#   'channel_title': 'ABP NEWS',
#   'creation_date': '2012-06-01T10:23:46.000Z',
#   'country': 'IN',
#   'view_count': 4283555008,
#   'comment_count': 0,
#   'subscriber_count': 17300000,
#   'video_count': 132845},
#  {'Unnamed: 0': 182,
#   'channel_id': 'UCttspZesZIDEwwpVIgoZtWQ',
#   'channel_title': 'IndiaTV',
#   'creation_date': '2006-08-26T14:47:52.000Z',
#   'country': 'IN',
#   'view_count': 5458124104,
#   'comment_count': 0,
#   'subscriber_count': 15600000,
#   'video_count': 143919},
#  {'Unnamed: 0': 183,
#   'channel_id': 'UCZkURf9tDolFOeuw_4RD7XQ',
#   'channel_title': 'Demi Lovato',
#   'creation_date': '2008-01-30T05:20:00.000Z',
#   'country': 'Null',
#   'view_count': 399913938,
#   'comment_count': 0,
#   'subscriber_count': 15600000,
#   'video_count': 189},
#  {'Unnamed: 0': 184,
#   'channel_id': 'UC_vcKmg67vjMP7ciLnSxSHQ',
#   'channel_title': 'Amit Bhadana',
#   'creation_date': '2012-10-24T13:00:34.000Z',
#   'country': 'IN',
#   'view_count': 1302309623,
#   'comment_count': 0,
#   'subscriber_count': 17300000,
#   'video_count': 65},
#  {'Unnamed: 0': 185,
#   'channel_id': 'UC4PooiX37Pld1T8J5SYT-SQ',
#   'channel_title': 'Good Mythical Morning',
#   'creation_date': '2008-09-17T14:37:49.000Z',
#   'country': 'US',
#   'view_count': 5909475318,
#   'comment_count': 0,
#   'subscriber_count': 15900000,
#   'video_count': 2361},
#  {'Unnamed: 0': 186,
#   'channel_id': 'UCsTcErHg8oDvUnTzoqsYeNw',
#   'channel_title': 'Unbox Therapy',
#   'creation_date': '2010-12-21T08:00:23.000Z',
#   'country': 'Null',
#   'view_count': 3292486951,
#   'comment_count': 0,
#   'subscriber_count': 15700000,
#   'video_count': 1703},
#  {'Unnamed: 0': 187,
#   'channel_id': 'UCgtNC51EUSgcZ6kKyVoPxKA',
#   'channel_title': 'Becky G',
#   'creation_date': '2011-09-06T15:39:33.000Z',
#   'country': 'US',
#   'view_count': 35801057,
#   'comment_count': 0,
#   'subscriber_count': 14900000,
#   'video_count': 56},
#  {'Unnamed: 0': 188,
#   'channel_id': 'UCNL1ZadSjHpjm4q9j2sVtOA',
#   'channel_title': 'Lady Gaga',
#   'creation_date': '2008-05-15T17:02:12.000Z',
#   'country': 'Null',
#   'view_count': 116203032,
#   'comment_count': 0,
#   'subscriber_count': 14800000,
#   'video_count': 163},
#  {'Unnamed: 0': 189,
#   'channel_id': 'UCFkoPRmuxqr37jvGmmpzhzQ',
#   'channel_title': 'MalumaVEVO',
#   'creation_date': '2011-06-15T21:07:25.000Z',
#   'country': 'Null',
#   'view_count': 12695033919,
#   'comment_count': 0,
#   'subscriber_count': 14700000,
#   'video_count': 111},
#  {'Unnamed: 0': 190,
#   'channel_id': 'UCCI5Xsd_gCbZb9eTeOf9FdQ',
#   'channel_title': 'Like Nastya',
#   'creation_date': '2016-01-14T16:49:19.000Z',
#   'country': 'RU',
#   'view_count': 4763566601,
#   'comment_count': 0,
#   'subscriber_count': 14900000,
#   'video_count': 237},
#  {'Unnamed: 0': 191,
#   'channel_id': 'UCi9cDo6239RAzPpBZO9y5SA',
#   'channel_title': 'Lele Pons',
#   'creation_date': '2015-09-19T01:11:59.000Z',
#   'country': 'US',
#   'view_count': 3308902633,
#   'comment_count': 0,
#   'subscriber_count': 15300000,
#   'video_count': 132},
#  {'Unnamed: 0': 192,
#   'channel_id': 'UCIR9VKPE70KJ4DX2zCjHObw',
#   'channel_title': 'Canal IN',
#   'creation_date': '2017-07-21T20:36:59.000Z',
#   'country': 'BR',
#   'view_count': 1725233195,
#   'comment_count': 0,
#   'subscriber_count': 14600000,
#   'video_count': 334},
#  {'Unnamed: 0': 193,
#   'channel_id': 'UCPDis9pjXuqyI7RYLJ-TTSA',
#   'channel_title': 'FailArmy',
#   'creation_date': '2011-07-05T10:47:32.000Z',
#   'country': 'US',
# ...
#   'video_count': 1041},
#  {'Unnamed: 0': 365,
#   'channel_id': 'UChLN0bJgq6d15OK2HVB4YTg',
#   'channel_title': 'SIS vs BRO',
#   'creation_date': '2016-03-03T16:06:20.000Z',
#   'country': 'CA',
#   'view_count': 4637337575,
#   'comment_count': 0,
#   'subscriber_count': 11400000,
#   'video_count': 321},
#  {'Unnamed: 0': 366,
#   'channel_id': 'UC6sSkkemzPjmrzS0Y0V_2zw',
#   'channel_title': 'Tiana',
#   'creation_date': '2015-04-05T10:35:02.000Z',
#   'country': 'GB',
#   'view_count': 2748462824,
#   'comment_count': 0,
#   'subscriber_count': 11200000,
#   'video_count': 700},
#  {'Unnamed: 0': 367,
#   'channel_id': 'UCl_AQeO6ynSDRSjclc1e16Q',
#   'channel_title': 'FitDance',
#   'creation_date': '2013-12-26T19:41:03.000Z',
#   'country': 'BR',
#   'view_count': 3704164219,
#   'comment_count': 0,
#   'subscriber_count': 11300000,
#   'video_count': 1376},
#  {'Unnamed: 0': 368,
#   'channel_id': 'UCs2t9DlvAuyTBkvk2djGZKw',
#   'channel_title': 'Genierock',
#   'creation_date': '2008-03-09T10:12:35.000Z',
#   'country': 'TH',
#   'view_count': 9274672326,
#   'comment_count': 0,
#   'subscriber_count': 11200000,
#   'video_count': 1016},
#  {'Unnamed: 0': 369,
#   'channel_id': 'UCR3vcUrhFUdzagng58ueI2w',
#   'channel_title': 'Invento na Hora',
#   'creation_date': '2014-10-18T16:49:42.000Z',
#   'country': 'Null',
#   'view_count': 2079534948,
#   'comment_count': 0,
#   'subscriber_count': 11300000,
#   'video_count': 706},
#  {'Unnamed: 0': 370,
#   'channel_id': 'UCxMAbVFmxKUVGAll0WVGpFw',
#   'channel_title': 'Cardi B',
#   'creation_date': '2016-12-01T14:44:07.000Z',
#   'country': 'Null',
#   'view_count': 3484373068,
#   'comment_count': 0,
#   'subscriber_count': 11700000,
#   'video_count': 39},
#  {'Unnamed: 0': 371,
#   'channel_id': 'UCwHE1kM1CPJd_pI9FQ0-4dg',
#   'channel_title': 'shfa',
#   'creation_date': '2015-03-29T08:55:45.000Z',
#   'country': 'AE',
#   'view_count': 3833604164,
#   'comment_count': 0,
#   'subscriber_count': 11400000,
#   'video_count': 418},
#  {'Unnamed: 0': 372,
#   'channel_id': 'UCf31Gf5nCU8J6eUlr7QSU0w',
#   'channel_title': 'Marmok',
#   'creation_date': '2008-04-27T20:24:32.000Z',
#   'country': 'Null',
#   'view_count': 1700836863,
#   'comment_count': 0,
#   'subscriber_count': 11100000,
#   'video_count': 272},
#  {'Unnamed: 0': 373,
#   'channel_id': 'UCbt4SegZBQLeXMTMvnrfZtw',
#   'channel_title': 'Gato Galactico',
#   'creation_date': '2013-04-02T19:53:37.000Z',
#   'country': 'BR',
#   'view_count': 2677473569,
#   'comment_count': 0,
#   'subscriber_count': 11200000,
#   'video_count': 1059},
#  {'Unnamed: 0': 374,
#   'channel_id': 'UCKlhpmbHGxBE6uw9B_uLeqQ',
#   'channel_title': 'Sky Does Everything',
#   'creation_date': '2011-02-28T04:00:46.000Z',
#   'country': 'US',
#   'view_count': 3840641289,
#   'comment_count': 0,
#   'subscriber_count': 11500000,
#   'video_count': 1959},
#  {'Unnamed: 0': 375,
#   'channel_id': 'UCCEmjNPpJYhGDgaEqeeA4HA',
#   'channel_title': 'TheGrefg',
#   'creation_date': '2012-01-30T19:13:31.000Z',
#   'country': 'ES',
#   'view_count': 3193184737,
#   'comment_count': 0,
#   'subscriber_count': 11600000,
#   'video_count': 2630},
#  {'Unnamed: 0': 376,
#   'channel_id': 'UC-J-KZfRV8c13fOCkhXdLiQ',
#   'channel_title': 'Dua Lipa',
#   'creation_date': '2011-02-05T14:36:44.000Z',
#   'country': 'GB',
#   'view_count': 3881487039,
#   'comment_count': 0,
#   'subscriber_count': 11400000,
#   'video_count': 93},
#  {'Unnamed: 0': 377,
#   'channel_id': 'UCNdqe5zJ6k-i7XKoYWA4Z2g',
#   'channel_title': 'Wassabi',
#   'creation_date': '2006-01-25T21:36:06.000Z',
#   'country': 'US',
#   'view_count': 4259970610,
#   'comment_count': 0,
#   'subscriber_count': 11500000,
#   'video_count': 962},
#  {'Unnamed: 0': 378,
#   'channel_id': 'UCG0HA4uyuuzPzeq_US_ywVg',
#   'channel_title': 'Enes Batur',
#   'creation_date': '2012-11-18T17:55:16.000Z',
#   'country': 'TR',
#   'view_count': 5488602237,
#   'comment_count': 0,
#   'subscriber_count': 11300000,
#   'video_count': 1815},
#  {'Unnamed: 0': 379,
#   'channel_id': 'UCNbwP-bKUlKrE_5qDwvFILQ',
#   'channel_title': 'Antrax',
#   'creation_date': '2015-05-25T00:45:42.000Z',
#   'country': 'MX',
#   'view_count': 1581939359,
#   'comment_count': 0,
#   'subscriber_count': 11300000,
#   'video_count': 396},
#  {'Unnamed: 0': 380,
#   'channel_id': 'UC9lSZSYpDDE18hoFA7YlBpw',
#   'channel_title': 'Tfue',
#   'creation_date': '2014-05-23T05:46:36.000Z',
#   'country': 'US',
#   'view_count': 1111838814,
#   'comment_count': 0,
#   'subscriber_count': 11300000,
#   'video_count': 594},
#  {'Unnamed: 0': 381,
#   'channel_id': 'UCtylTUUVIGY_i5afsQYeBZA',
#   'channel_title': 'Lyrical Lemonade',
#   'creation_date': '2013-03-25T21:25:06.000Z',
#   'country': 'US',
#   'view_count': 4115431982,
#   'comment_count': 0,
#   'subscriber_count': 11500000,
#   'video_count': 345},
#  {'Unnamed: 0': 382,
#   'channel_id': 'UCM44x9uWlx__9M9Y2IFhxzQ',
#   'channel_title': 'HiMan',
#   'creation_date': '2014-10-16T08:45:28.000Z',
#   'country': 'RU',
#   'view_count': 814509174,
#   'comment_count': 0,
#   'subscriber_count': 11400000,
#   'video_count': 146},
#  {'Unnamed: 0': 383,
#   'channel_id': 'UCiMhD4jzUqG-IgPzUmmytRQ',
#   'channel_title': 'Queen Official',
#   'creation_date': '2008-07-07T13:35:27.000Z',
#   'country': 'GB',
#   'view_count': 5615125048,
#   'comment_count': 0,
#   'subscriber_count': 11000000,
#   'video_count': 798},
#  {'Unnamed: 0': 384,
#   'channel_id': 'UCvA9_f5Lwk-poMynabtrZPg',
#   'channel_title': 'Rans Entertainment',
#   'creation_date': '2015-12-27T15:23:13.000Z',
#   'country': 'ID',
#   'view_count': 1719828342,
#   'comment_count': 0,
#   'subscriber_count': 11200000,
#   'video_count': 896},
#  {'Unnamed: 0': 385,
#   'channel_id': 'UCBwSufNse8VMBvQM_rCSvgQ',
#   'channel_title': 'Morgz',
#   'creation_date': '2014-06-10T17:42:37.000Z',
#   'country': 'GB',
#   'view_count': 1953228003,
#   'comment_count': 0,
#   'subscriber_count': 10800000,
#   'video_count': 610},
#  {'Unnamed: 0': 386,
#   'channel_id': 'UCwQSkyrft0ohf-ra21yIs9Q',
#   'channel_title': 'EU FICO LOKO',
#   'creation_date': '2010-06-11T22:06:25.000Z',
#   'country': 'Null',
#   'view_count': 1000710666,
#   'comment_count': 0,
#   'subscriber_count': 11200000,
#   'video_count': 899},
#  {'Unnamed: 0': 387,
#   'channel_id': 'UChPa3fnlI3RKuzEbeEPKRFw',
#   'channel_title': 'Everson Zoio',
#   'creation_date': '2009-03-26T22:02:20.000Z',
#   'country': 'BR',
#   'view_count': 741048256,
#   'comment_count': 0,
#   'subscriber_count': 11300000,
#   'video_count': 392},
#  {'Unnamed: 0': 388,
#   'channel_id': 'UCgdnrd2Ae_H07_N8j1l18Xw',
#   'channel_title': 'Dani Russo Tv',
#   'creation_date': '2014-07-15T03:28:04.000Z',
#   'country': 'BR',
#   'view_count': 529561410,
#   'comment_count': 0,
#   'subscriber_count': 11300000,
#   'video_count': 170},
#  {'Unnamed: 0': 389,
#   'channel_id': 'UCE76CBkDX591pxzps6bySOw',
#   'channel_title': 'Super Polina',
#   'creation_date': '2014-07-08T13:34:05.000Z',
#   'country': 'US',
#   'view_count': 3154031238,
#   'comment_count': 0,
#   'subscriber_count': 10900000,
#   'video_count': 348},
#  {'Unnamed: 0': 390,
#   'channel_id': 'UC56cowXhoqRWHeqfSJkIQaA',
#   'channel_title': 'Bounce Patrol - Kids Songs',
#   'creation_date': '2013-01-01T01:37:50.000Z',
#   'country': 'AU',
#   'view_count': 6243918356,
#   'comment_count': 0,
#   'subscriber_count': 11000000,
#   'video_count': 164},
#  {'Unnamed: 0': 391,
#   'channel_id': 'UCu6oyJJ6PlkeNNv6n26ZNyA',
#   'channel_title': 'Troom Troom Es',
#   'creation_date': '2016-02-05T10:01:45.000Z',
#   'country': 'Null',
#   'view_count': 2631257823,
#   'comment_count': 0,
#   'subscriber_count': 10900000,
#   'video_count': 1020},
#  {'Unnamed: 0': 392,
#   'channel_id': 'UC1SqP7_RfOC9Jf9L_GRHANg',
#   'channel_title': 'AviciiOfficialVEVO',
#   'creation_date': '2011-11-29T14:45:01.000Z',
#   'country': 'Null',
#   'view_count': 6762152584,
#   'comment_count': 0,
#   'subscriber_count': 11300000,
#   'video_count': 142},
#  {'Unnamed: 0': 393,
#   'channel_id': 'UCe_vXdMrHHseZ_esYUskSBw',
#   'channel_title': 'CrazyRussianHacker',
#   'creation_date': '2012-05-18T19:29:15.000Z',
#   'country': 'US',
#   'view_count': 2690414457,
#   'comment_count': 0,
#   'subscriber_count': 11200000,
#   'video_count': 1440},
#  {'Unnamed: 0': 394,
#   'channel_id': 'UC4-TgOSMJHn-LtY4zCzbQhw',
#   'channel_title': 'ShawnMendesVEVO',
#   'creation_date': '2014-06-10T13:34:14.000Z',
#   'country': 'Null',
#   'view_count': 7300167467,
#   'comment_count': 0,
#   'subscriber_count': 11200000,
#   'video_count': 119},
#  {'Unnamed: 0': 395,
#   'channel_id': 'UCK9F8nycURBsR0YlrBsu1Ag',
#   'channel_title': 'Jingle Toons',
#   'creation_date': '2013-01-24T05:15:15.000Z',
#   'country': 'Null',
#   'view_count': 3800214467,
#   'comment_count': 0,
#   'subscriber_count': 11400000,
#   'video_count': 195},
#  {'Unnamed: 0': 396,
#   'channel_id': 'UC3RpTX6fEMJ6KBNTTgXJB9w',
#   'channel_title': '5incominutos',
#   'creation_date': '2010-07-25T19:13:23.000Z',
#   'country': 'Null',
#   'view_count': 832910461,
#   'comment_count': 0,
#   'subscriber_count': 10900000,
#   'video_count': 289},
#  {'Unnamed: 0': 397,
#   'channel_id': 'UCS3VJQpFmLbBd5qsWci9KPA',
#   'channel_title': 'Nao FunFun',
#   'creation_date': '2014-02-01T02:18:26.000Z',
#   'country': 'KR',
#   'view_count': 2642064,
#   'comment_count': 0,
#   'subscriber_count': 11400000,
#   'video_count': 156},
#  {'Unnamed: 0': 398,
#   'channel_id': 'UC_A7K2dXFsTMAciGmnNxy-Q',
#   'channel_title': 'Saregama Music',
#   'creation_date': '2013-01-04T10:53:12.000Z',
#   'country': 'IN',
#   'view_count': 3186085042,
#   'comment_count': 0,
#   'subscriber_count': 10900000,
#   'video_count': 3283},
#  {'Unnamed: 0': 400,
#   'channel_id': 'UCksqGNZCImjaDnKvRONwbdg',
#   'channel_title': '___________',
#   'creation_date': '2014-05-15T22:21:32.000Z',
#   'country': 'Null',
#   'view_count': 40,
#   'comment_count': 0,
#   'subscriber_count': 7,
#   'video_count': 1},
#  {'Unnamed: 0': 401,
#   'channel_id': 'UCBw-Dz6wHRkxiXKCLoWqDzA',
#   'channel_title': 'BCC Trolling',
#   'creation_date': '2011-05-12T22:00:33.000Z',
#   'country': 'GB',
#   'view_count': 3098221097,
#   'comment_count': 0,
#   'subscriber_count': 10600000,
#   'video_count': 3838},
#  {'Unnamed: 0': 402,
#   'channel_id': 'UCAoMPWcQKA_9Af5YhWdrZgw',
#   'channel_title': 'MyLifeAsEva',
#   'creation_date': '2011-07-25T01:31:39.000Z',
#   'country': 'US',
#   'view_count': 1146009872,
#   'comment_count': 0,
#   'subscriber_count': 10700000,
#   'video_count': 272},
#  {'Unnamed: 0': 403,
#   'channel_id': 'UCITqR49EAUY8i1vZtXTwe-A',
#   'channel_title': 'Dolan Twins',
#   'creation_date': '2014-03-10T00:51:49.000Z',
#   'country': 'Null',
#   'view_count': 1586515045,
#   'comment_count': 0,
#   'subscriber_count': 10600000,
#   'video_count': 252},
#  {'Unnamed: 0': 404,
#   'channel_id': 'UCKyU-wd-KY4PMOcOpPQgQcw',
#   'channel_title': 'Tlnovelas',
#   'creation_date': '2013-04-03T01:45:06.000Z',
#   'country': 'MX',
#   'view_count': 5993510141,
#   'comment_count': 0,
#   'subscriber_count': 10800000,
#   'video_count': 18557},
#  {'Unnamed: 0': 405,
#   'channel_id': 'UCDo9msNItILnyF_Y2eHaNQg',
#   'channel_title': 'RiceGum',
#   'creation_date': '2012-09-25T00:03:02.000Z',
#   'country': 'US',
#   'view_count': 2058883902,
#   'comment_count': 0,
#   'subscriber_count': 10700000,
#   'video_count': 318},
#  {'Unnamed: 0': 406,
#   'channel_id': 'UCay_OLhWtf9iklq8zg_or0g',
#   'channel_title': 'As/Is',
#   'creation_date': '2013-04-09T18:38:36.000Z',
#   'country': 'US',
#   'view_count': 10286973198,
#   'comment_count': 0,
#   'subscriber_count': 10700000,
#   'video_count': 3980},
#  {'Unnamed: 0': 407,
#   'channel_id': 'UCe_Fx4EZAgKjDz0aQ_Y7hSA',
#   'channel_title': 'Got Talent Global',
#   'creation_date': '2013-01-31T16:21:31.000Z',
#   'country': 'Null',
#   'view_count': 4223181056,
#   'comment_count': 0,
#   'subscriber_count': 10700000,
#   'video_count': 1440},
#  {'Unnamed: 0': 408,
#   'channel_id': 'UCt-am4x4ZyeohfgM85qFgdQ',
#   'channel_title': 'elliegoulding',
#   'creation_date': '2007-01-29T19:48:01.000Z',
#   'country': 'Null',
#   'view_count': 150127125,
#   'comment_count': 0,
#   'subscriber_count': 10600000,
#   'video_count': 72},
#  {'Unnamed: 0': 409,
#   'channel_id': 'UCXhDFaOPG2zhiYm9eXuMKkA',
#   'channel_title': 'MAIKI021',
#   'creation_date': '2008-01-22T22:22:56.000Z',
#   'country': 'BR',
#   'view_count': 1207022212,
#   'comment_count': 0,
#   'subscriber_count': 10800000,
#   'video_count': 1250},
#  {'Unnamed: 0': 410,
#   'channel_id': 'UCgefQJC5UgbWJHDxBqB4qVg',
#   'channel_title': 'Jesse',
#   'creation_date': '2009-11-10T03:10:03.000Z',
#   'country': 'US',
#   'view_count': 2110499771,
#   'comment_count': 0,
#   'subscriber_count': 10600000,
#   'video_count': 254},
#  {'Unnamed: 0': 411,
#   'channel_id': 'UC1r4VtVE__5K6c_L_3Vlxxg',
#   'channel_title': 'fouseyTUBE',
#   'creation_date': '2011-03-21T08:32:25.000Z',
#   'country': 'US',
#   'view_count': 1697084053,
#   'comment_count': 0,
#   'subscriber_count': 10600000,
#   'video_count': 181},
#  {'Unnamed: 0': 412,
#   'channel_id': 'UC70Dib4MvFfT1tU6MqeyHpQ',
#   'channel_title': 'Preston',
#   'creation_date': '2012-07-04T07:01:56.000Z',
#   'country': 'US',
#   'view_count': 3480169038,
#   'comment_count': 0,
#   'subscriber_count': 10700000,
#   'video_count': 3612},
#  {'Unnamed: 0': 413,
#   'channel_id': 'UCsm77kEHBDEPgD4Ir3jSRYg',
#   'channel_title': 'El Reino a Jugar',
#   'creation_date': '2015-03-03T14:01:27.000Z',
#   'country': 'AR',
#   'view_count': 4960763426,
#   'comment_count': 0,
#   'subscriber_count': 10600000,
#   'video_count': 407},
#  {'Unnamed: 0': 414,
#   'channel_id': 'UCyb0T6J6nL5ibo0HLRMINKw',
#   'channel_title': 'Galo Frito',
#   'creation_date': '2007-10-03T15:47:30.000Z',
#   'country': 'BR',
#   'view_count': 1725626688,
#   'comment_count': 0,
#   'subscriber_count': 10500000,
#   'video_count': 432},
#  {'Unnamed: 0': 415,
#   'channel_id': 'UCoTyVfIkM-hjz4JauDoVvog',
#   'channel_title': 'ExpCaseros',
#   'creation_date': '2012-09-18T12:47:28.000Z',
#   'country': 'ES',
#   'view_count': 2101605782,
#   'comment_count': 0,
#   'subscriber_count': 10700000,
#   'video_count': 738},
#  {'Unnamed: 0': 416,
#   'channel_id': 'UCV1JuyDF9Re3HyXFGeqnC7Q',
#   'channel_title': 'JesseAndMike',
#   'creation_date': '2007-04-29T00:26:41.000Z',
#   'country': 'US',
#   'view_count': 6914730047,
#   'comment_count': 0,
#   'subscriber_count': 10700000,
#   'video_count': 454},
#  {'Unnamed: 0': 417,
#   'channel_id': 'UC1OFDlfdRb6ma1ZGZd07gWA',
#   'channel_title': 'Miranda Sings',
#   'creation_date': '2008-01-31T00:27:47.000Z',
#   'country': 'Null',
#   'view_count': 2101969601,
#   'comment_count': 0,
#   'subscriber_count': 10800000,
#   'video_count': 828},
#  {'Unnamed: 0': 418,
#   'channel_id': 'UCoookXUzPciGrEZEXmh4Jjg',
#   'channel_title': 'Sesame Street',
#   'creation_date': '2006-01-16T00:56:52.000Z',
#   'country': 'US',
#   'view_count': 9393216505,
#   'comment_count': 0,
#   'subscriber_count': 10800000,
#   'video_count': 2900},
#  {'Unnamed: 0': 419,
#   'channel_id': 'UC24_Z2L-8Ki183AI9zJJzNQ',
#   'channel_title': 'TRANS7 OFFICIAL',
#   'creation_date': '2014-09-04T12:28:11.000Z',
#   'country': 'ID',
#   'view_count': 4440416092,
#   'comment_count': 0,
#   'subscriber_count': 10700000,
#   'video_count': 48585},
#  {'Unnamed: 0': 420,
#   'channel_id': 'UC-LPIU24bQXVljUXivKEeRQ',
#   'channel_title': 'StarPlus',
#   'creation_date': '2006-05-19T21:46:13.000Z',
#   'country': 'Null',
#   'view_count': 3223274932,
#   'comment_count': 0,
#   'subscriber_count': 10500000,
#   'video_count': 8905},
#  {'Unnamed: 0': 421,
#   'channel_id': 'UCqFhfan_P2AmGVB1X2B-3Aw',
#   'channel_title': 'Farruko',
#   'creation_date': '2009-10-30T19:04:17.000Z',
#   'country': 'US',
#   'view_count': 732584869,
#   'comment_count': 0,
#   'subscriber_count': 10800000,
#   'video_count': 129},
#  {'Unnamed: 0': 422,
#   'channel_id': 'UCnOVVuoLJ_1YY8A0V802wHA',
#   'channel_title': 'RomanAtwood',
#   'creation_date': '2009-11-18T17:22:03.000Z',
#   'country': 'Null',
#   'view_count': 1498276258,
#   'comment_count': 0,
#   'subscriber_count': 10600000,
#   'video_count': 117},
#  {'Unnamed: 0': 423,
#   'channel_id': 'UCshoKvlZGZ20rVgazZp5vnQ',
#   'channel_title': 'CaptainSparklez',
#   'creation_date': '2010-07-20T19:38:14.000Z',
#   'country': 'US',
#   'view_count': 3568843507,
#   'comment_count': 0,
#   'subscriber_count': 10700000,
#   'video_count': 5067},
#  {'Unnamed: 0': 424,
#   'channel_id': 'UCt4atlExw8aj3Bm79nv1fig',
#   'channel_title': 'Round2hell',
#   'creation_date': '2016-10-20T07:58:14.000Z',
#   'country': 'IN',
#   'view_count': 902828606,
#   'comment_count': 0,
#   'subscriber_count': 10600000,
#   'video_count': 56}]

# %% [markdown]
# # INSERT to MySQL

# %%
#Insert function for all channel data

def insert_channel(parsed_channels_data):
    """
    Inserts parsed_channel_data into the channels table in the youtube MySQL database.
    """
    
    channel_tuples = [(parsed_channel_data['channel_id'],
                     parsed_channel_data['channel_title'],
                     parsed_channel_data['creation_date'],
                     parsed_channel_data['country'],
                     parsed_channel_data['view_count'],
                     parsed_channel_data['comment_count'],
                     parsed_channel_data['subscriber_count'],
                     parsed_channel_data['video_count']) for parsed_channel_data in parsed_channels_data]
#     for single_tuple in channel_tuples:    
#         print(single_tuple[4])
    insert_statement = """
        INSERT INTO channels 
            (channel_id, 
            channel_title, 
            creation_date, 
            country, 
            view_count,
            comment_count,
            subscriber_count,
            video_count
            )
            
        VALUES
            (%s, %s, %s, %s, %s, %s, %s, %s);"""
    
        
    cursor.executemany(insert_statement,channel_tuples)
    db.commit()
    
insert_channel(first_channels_dict)

# cursor.close()
# db.close()

# %%
#Get genres only from channel data
genres_only = first_channels[['channel_id','genres']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6c0a7c504dd8> in <module>
#       1 #Get genres only from channel data
# ----> 2 genres_only = first_channels[['channel_id','genres']]
#
# NameError: name 'first_channels' is not defined

# %%
#Find unique genres
#find genre_channels tuple with channel id 

def separate_genres(genres_only):
    genres_list = []
    genre_channel_tuples = []
    for index, genres in genres_only['genres'].items():
        cleaned_genres = genres.replace("[", "").replace("]", "").replace("'", "")
        splt_genres = cleaned_genres.split(", ")
        
        for item in splt_genres:
            genres_list.append(item)
            tuple_ = genres_only['channel_id'][index], item
            genre_channel_tuples.append(tuple_)
    
    return (set(genres_list)), genre_channel_tuples

unique_genres, genre_channels_tuples = separate_genres(genres_only)
# Out:
# 1171

# %%
#Dictionary and df of genres only
genres_dict = genres_only.to_dict(orient='records')
unique_genres_df = pd.DataFrame(unique_genres,columns=['genre'])

# %%
#insert genres and channel ids into mysql using the genre tuples

def insert_genre(genre_data):

    insert_statement = """
        INSERT INTO genres
            (channel_id,
            genre_name 
            )
            
        VALUES
            (%s, %s);"""
        
    cursor.executemany(insert_statement, genre_data)
    db.commit()
    
insert_genre(genre_channels_tuples)

# %%
# cursor.close()
# db.close()

# %% [markdown]
# # Query from MySQL

# %%
#Testing the data
db = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = "youtube")

cursor = db.cursor()


channel_info = cursor.execute("""SELECT * FROM youtube.channels""")
channel_info = pd.DataFrame(cursor.fetchall())
channel_info.columns = [x[0] for x in cursor.description]

# %%
channel_info.head()
# Out:
#                  channel_id       channel_title       creation_date country  \
# 0  UC-8Q-hLdECwQmaWNwXitYDw       KatyPerryVEVO 2009-12-13 03:04:53      US
# 1  UC-lHJZR3Gqxm24_Vd_AJ5Yw           PewDiePie 2010-04-29 10:54:00      US
# 2  UC-SV8-bUJfXjrRMnp7F8Wzw  Roman Atwood Vlogs 2013-08-12 19:42:23      US
# 3  UC-yXuc1__OzjwpsJPlxYUCQ     WORLDSTARHIPHOP 2008-11-08 13:30:04      US
# 4  UC0C-w0YjGpqDXGB8IHb662A          Ed Sheeran 2006-08-08 13:59:50    Null
#
#     view_count  comment_count  subscriber_count  video_count
# 0  18376186831              0          25900000          136
# 1  23936169110              0         102000000         4010
# 2   5157196361              0          15400000         1651
# 3  14265494805              0          22300000         4516
# 4  18525689218              0          42700000          158

# %%
channel_info.video_count.describe()
channel_info.subscriber_count.describe()
# Out:
# count    2.430000e+02
# mean     2.214198e+07
# std      1.208553e+07
# min      1.320000e+07
# 25%      1.515000e+07
# 50%      1.890000e+07
# 75%      2.510000e+07
# max      1.180000e+08
# Name: subscriber_count, dtype: float64

# %% [markdown]
# GENRE IMPORT

# %%
#Testing the data
db = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = "youtube")

cursor = db.cursor()
genre_info = cursor.execute("""SELECT * FROM youtube.genres""")
genre_info = pd.DataFrame(cursor.fetchall())
genre_info.columns = [x[0] for x in cursor.description]

# %%
genre_info.head()
# Out:
#          genre_name                channel_id
# 0     Hip Hop Music  UCa10nxShhzNrCE1o2ZOPztg
# 1  Electronic Music  UCa10nxShhzNrCE1o2ZOPztg
# 2         Pop Music  UCa10nxShhzNrCE1o2ZOPztg
# 3             Music  UCa10nxShhzNrCE1o2ZOPztg
# 4              Film  UClZkHt2kNIgyrTTPnSQV3SA

# %% [markdown]
# GENRES AND CHANNELS - Join

# %%
#Testing the data
db = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = "youtube")

cursor = db.cursor()
genre_channel_info = cursor.execute("""SELECT * FROM channels JOIN genres USING(channel_id)""")
genre_channel_info = pd.DataFrame(cursor.fetchall())
genre_channel_info.columns = [x[0] for x in cursor.description]
# genre_channel_info.head()

# %%
genre_channel_info = cursor.execute("""
                    SELECT 
                    gr.genre_name,
                    AVG(ch.view_count), 
                    AVG(ch.video_count), 
                    AVG(ch.subscriber_count), 
                    COUNT(gr.genre_name) 
                    FROM 
                    youtube.channels ch 
                    JOIN 
                    youtube.genres gr 
                    ON 
                    ch.channel_id = gr.channel_id
                    GROUP BY 
                    genre_name
                    ORDER BY COUNT(gr.genre_name) DESC
                    """)

genre_avg_table = pd.DataFrame(cursor.fetchall())
genre_avg_table.columns = [x[0] for x in cursor.description]

# %%
genre_avg_table.head(3)
# Out:
#               genre_name AVG(ch.view_count) AVG(ch.video_count)  \
# 0          Entertainment    6301253721.9783           6548.2870
# 1                  Music    7300163779.3277           1910.8475
# 2  Lifestyle (Sociology)    4262519444.4722           2157.2778
#
#   AVG(ch.subscriber_count)  COUNT(gr.genre_name)
# 0            18861739.1304                   230
# 1            19503954.8023                   177
# 2            15781944.4931                   144

# %% [markdown]
# # Statistical Analysis

# %% [markdown]
# $$H_0: \text {All genres are equally likely to be in top channels}$$
# $$𝐻0=𝜇1=𝜇1=𝜇3$$
#
# $$H_1: \text {Not all genres are equally likely to be in top channels}$$
# $$𝐻𝑎  \text { :H0 is not true}$$

# %%
all_genres = genre_channel_info[genre_channel_info.isin(s.index[s >5]).values]

# %%
# #THIS IS THE DATA SET FOR THE ANOVA
# s = genre_channel_info['genre_name'].value_counts()
# new_genre_channel = genre_channel_info[genre_channel_info.isin(s.index[s >70]).values]
# new_genre_channel['genre_name'].value_counts()

# #THIS TABLE IS JUST genre and viebw_counts
# prepivot = pd.concat([new_genre_channel['genre_name'], new_genre_channel['view_count']], axis=1)

# # pd.DataFrame(prepivot.groupby("genre_name")['view_count'].sum())

# %% [markdown]
# ONE-WAY ANOVA:
#
# Independent variable is discrete.
# Dependendent variable should be continuous.

# %%
#Cutting the genres to TOP 3
s = genre_channel_info['genre_name'].value_counts()
new_genre_channel = genre_channel_info[genre_channel_info.isin(s.index[s >100]).values]
new_genre_channel['genre_name'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-31b7eb5d0278> in <module>
#       1 #Cutting the genres to TOP 3
# ----> 2 s = genre_channel_info['genre_name'].value_counts()
#       3 new_genre_channel = genre_channel_info[genre_channel_info.isin(s.index[s >100]).values]
#       4 new_genre_channel['genre_name'].value_counts()
#
# NameError: name 'genre_channel_info' is not defined

# %%
#Create Anova Table for Genres and View_Counts
# 'view_count~genre_name'
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.stats import norm

def run_anova_table(dependent, independent, data_):  
    genre_stats = ols(f"{dependent}~{independent}", data=data_).fit()  
    anova_table = sm.stats.anova_lm(genre_stats, type=2)
    
    return  genre_stats.summary(), anova_table

# %%
#ALL ANOVA TESTS FOR GENRES

#view count ANOVA summary and ANOVA table
view_count_summary, view_count_table = run_anova_table('view_count', 'genre_name', new_genre_channel)

#subscriber count ANOVA summary and ANOVA table
subscriber_count_summary, subscriber_count_table = run_anova_table('subscriber_count', 'genre_name', new_genre_channel)

#video count ANOVA summary and ANOVA table
video_count_summary, video_count_table = run_anova_table('video_count', 'genre_name', new_genre_channel)

view_count_table
# Out:
#                df        sum_sq       mean_sq         F    PR(>F)
# genre_name    2.0  7.503947e+20  3.751974e+20  6.110712  0.002373
# Residual    548.0  3.364717e+22  6.139995e+19       NaN       NaN

# %%
#Perform a post-hoc test on the data to detemine all comparisons
from statsmodels.stats.multicomp import (pairwise_tukeyhsd,
                                         MultiComparison)

def get_tukey(dependent, independent):
# Set up the data for comparison (creates a specialised object)
    MultiComp = MultiComparison(new_genre_channel[dependent],
                            new_genre_channel[independent])
    
    return MultiComp.tukeyhsd().summary()

# %%
#ALL TUKEY TESTS FOR GENRES

#post_hoc comparison for view_counts and genres - not significant
view_count_tukey = get_tukey('view_count', 'genre_name')

#post_hoc comparison for subscriber counts and genres - not significant
subscriber_count_tukey = get_tukey('subscriber_count', 'genre_name')

# post_hoc comparison for video counts and genres - significant
video_count_tukey = get_tukey('video_count', 'genre_name')

subscriber_count_tukey
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
video_count_tukey
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
view_count_tukey
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
#Set of unique Genre Names
uniques = set(new_genre_channel['genre_name'])
uniques
# Out:
# {'Entertainment', 'Lifestyle (Sociology)', 'Music'}

# %%
from statsmodels.formula.api import ols

k = len(uniques)# number of conditions
N = len(new_genre_channel.values)  # conditions times participants
n = new_genre_channel.groupby('genre_name').size()[0:3] #Participants in each condition

DFbetween = k - 1
DFwithin = N - k
DFtotal = N - 1

# %%
#Manually running a ONE-WAY ANOVA to make sure the other is operating correctly
import statsmodels.api as sm
import scipy.stats as stats
stats.f_oneway(new_genre_channel['view_count'][new_genre_channel['genre_name'] == 'Entertainment'], 
             new_genre_channel['view_count'][new_genre_channel['genre_name'] == 'Lifestyle (Sociology)'],
             new_genre_channel['view_count'][new_genre_channel['genre_name'] == 'Music'])
# Out:
# F_onewayResult(statistic=2.799917038805087, pvalue=0.06220580181786833)

# %%
#Regression Analysis for Video Count and View Count

def run_regression(dependent, independent, data_):  
    genre_stats = ols(f"{dependent}~{independent}", data=data_).fit()  
    p = genre_stats.f_pvalue
    return genre_stats.summary(), p

run_regression('view_count', 'video_count', channel_info)
# Out:
# (<class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:             view_count   R-squared:                       0.043
#  Model:                            OLS   Adj. R-squared:                  0.041
#  Method:                 Least Squares   F-statistic:                     17.96
#  Date:                Fri, 15 Nov 2019   Prob (F-statistic):           2.81e-05
#  Time:                        12:40:41   Log-Likelihood:                -9579.9
#  No. Observations:                 397   AIC:                         1.916e+04
#  Df Residuals:                     395   BIC:                         1.917e+04
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ===============================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
#  -------------------------------------------------------------------------------
#  Intercept    5.987e+09   3.82e+08     15.682      0.000    5.24e+09    6.74e+09
#  video_count  8.613e+04   2.03e+04      4.238      0.000    4.62e+04    1.26e+05
#  ==============================================================================
#  Omnibus:                      430.747   Durbin-Watson:                   2.030
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):            29250.336
#  Skew:                           4.681   Prob(JB):                         0.00
#  Kurtosis:                      43.995   Cond. No.                     1.95e+04
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The condition number is large, 1.95e+04. This might indicate that there are
#  strong multicollinearity or other numerical problems.
#  """, 2.8125388045932456e-05)

# %%
#Looking at regression output for viewcount and videocount
video_count_t = 8.61/2.03
t_square= 4.238**2
p_value = 2.8125388045932456e-05
# Out:
# 4.241379310344827

# %%
genre_channel_means = new_genre_channel.groupby(['genre_name']).mean().head()
genre_channel_means
# Out:
#                     view_count  comment_count  subscriber_count   video_count
# genre_name
# Action Game       8.384121e+09            0.0      2.583333e+07   3072.888889
# Electronic Music  8.847467e+09            0.0      2.278750e+07   1402.875000
# Entertainment     8.134199e+09            0.0      2.301164e+07   6990.520548
# Film              1.228908e+10            0.0      2.353962e+07  10235.188679
# Food              5.496272e+09            0.0      2.121250e+07   1740.687500

# %% [markdown]
# # Plotting

# %% [markdown]
# Data Visualizations for Analytics

# %%
#Visualization of view counts and genre tags

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.figure(figsize=(12, 6))

sns.set(style="ticks", palette="vlag")

genre_plot = sns.boxplot(x = all_genres['view_count'], y=all_genres['genre_name'], palette="vlag")
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
genre_plot.set(xlabel = "View Count (Billions)", ylabel='Channel Genre Tag', title='View Count by Genre Tag')
# Out:
# [Text(0, 0.5, 'Channel Genre Tag'),
#  Text(0.5, 0, 'View Count (Billions)'),
#  Text(0.5, 1.0, 'View Count by Genre Tag')]

# %%
all_genres['genre_name'].value_counts().head()

# %%
#Visualization of Genre Tag and Subscriber Counts
plt.figure(figsize=(12, 6))

sns.set(style="ticks", palette="vlag")

genre_plot = sns.boxplot(x = all_genres['subscriber_count'], y=all_genres['genre_name'], palette="vlag")
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
genre_plot.set(xlabel = "Subscriber Count(Millions)", ylabel='Channel Genre Tag', title='Subscriber Count by Genre Tag')
# Out:
# [Text(0, 0.5, 'Channel Genre Tag'),
#  Text(0.5, 0, 'Subscriber Count(Millions)'),
#  Text(0.5, 1.0, 'Subscriber Count by Genre Tag')]

# %%
#Box plot representing only TOP 3 genre data and view_counts
sns.boxplot(x=new_genre_channel['genre_name'], y =new_genre_channel['view_count'])

genre_plot.set(xlabel = "Subscriber Count(Millions)", ylabel='Channel Genre Tag', title='Subscriber Count by Genre Tag')

# %%
test = genre_avg_table.head(3)

# %%
#Visualization of Subscriber Count, View Count, and Video Count by Genre

grid = (3,3) # Make a 2x2 axis grid to plot four plots in the same figure
fig = plt.figure(figsize=(14,14))
ax1 = plt.subplot2grid(grid, (0,0)) # First ax in position (0,0) (top left)
ax2 = plt.subplot2grid(grid, (0,1)) # Second ax in position (0,1) (top right)
ax3 = plt.subplot2grid(grid, (0,2)) # Third ax in position (1,0) (bottom left)


sns.barplot(x=test['genre_name'],y =test['AVG(ch.subscriber_count)'], ax=ax1)
ax1.set_title('Subscriber Count by Genre Tag');
ax1.set_xlabel('Genre Tag'), ax1.set_ylabel('Total Subscriber Count');

sns.barplot(x=test['genre_name'],y =test['AVG(ch.view_count)'], ax=ax2)
ax2.set_title('View Count by Genre Tag');
ax2.set_xlabel('Genre Tag'), ax2.set_ylabel('Total View Count');

sns.barplot(x=test['genre_name'],y =test['AVG(ch.video_count)'], ax=ax3)
ax3.set_title('Video Count by Genre Tag');
ax3.set_xlabel('Genre Tag'), ax3.set_ylabel('Total Video Count');

plt.setp(axes, yticks=[])
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2a436cd947ac> in <module>
#       2
#       3 grid = (3,3) # Make a 2x2 axis grid to plot four plots in the same figure
# ----> 4 fig = plt.figure(figsize=(14,14))
#       5 ax1 = plt.subplot2grid(grid, (0,0)) # First ax in position (0,0) (top left)
#       6 ax2 = plt.subplot2grid(grid, (0,1)) # Second ax in position (0,1) (top right)
#
# NameError: name 'plt' is not defined
